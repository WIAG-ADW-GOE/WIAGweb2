# %% [markdown]
# Run the line below (without the # symbol) to install pandas if not already installed

# %%
# !py -m pip install pandas

# %%
import requests
import csv
import os
import pandas as pd
import json
import re
import time
from datetime import datetime, timedelta
import math
import traceback

# %%
input_path = "C:\\Users\\khan32\\Documents\\factgrid_py\\test"
# input_path = "."

# %%
output_path = input_path

# %%
place_name = "Bamberg"

# %%
today_string = datetime.now().strftime('%Y-%m-%d')

# %%
# SELECT * FROM `role` r INNER JOIN url_external u on r.id = u.item_id where u.authority_id = 42

# %% [markdown]
# Export the results from the query from https://vwebfile.gwdg.de/phpmyadmin
# ```sql
# SELECT * FROM role r
# LEFT JOIN (
#     select * from url_external where authority_id = 42
# ) u on r.id = u.item_id;
# ```
# from the main wiag database in the csv format.
#
# Rename it to include the date. An example filename would be `role_2024_04_24.csv`

# %%
input_file = f"role_2024_06_10.csv"
input_path_file = os.path.join(input_path, input_file)
wiag_roles_df = pd.read_csv(input_path_file, names=['id', 'note', 'name', 'comment', 'gs_reg_id', 'generic_term', 'plural', 'definition', 'role_gp_fg_id', 'gender', 'lang', 'role_group_id','r_id','item_id','r_note','authority_id','role_fg_id','r_comment'])
len(wiag_roles_df)
# Out:
# 263

# %% [markdown]
# ### Download data from wiag
# https://wiag-vokabulare.uni-goettingen.de/query/can

# %%
input_file = f"WIAG-Domherren-DB-Ämter_2024-06-10.csv"
input_path_file = os.path.join(input_path, input_file)
role_all_df = pd.read_csv(input_path_file, sep=';')
len(role_all_df)
# Out:
# 2827

# %%
last_modified = datetime.fromtimestamp(os.path.getmtime(input_file))
now = datetime.now()
assert last_modified.day == now.day and last_modified.month == now.month, f"The file was last updated on {last_modified.strftime('%d.%m')}"

# %% [markdown]
# ### ERROR: If you get an error when you run the line above this means that the file was not updated today.
# A few solutions:
# * update the file again by downloading it again
# * change the file name to something correct
# * (not recommended) continue if you are sure that you need to use old data.

# %%
len(role_all_df)
# Out:
# 2827

# %%
role_all_df.head()
# Out:
#                    person_id     id       name            role_group  \
# 0  WIAG-Pers-CANON-19874-001  19230  Dompropst  Leitungsamt Domstift
# 1  WIAG-Pers-CANON-19937-001  21185   Domdekan  Leitungsamt Domstift
# 2  WIAG-Pers-CANON-18893-001  22200  Domkustos  Leitungsamt Domstift
# 3  WIAG-Pers-CANON-18987-001  20018    Domherr          Amt Domstift
# 4  WIAG-Pers-CANON-18979-001  20953    Domherr          Amt Domstift
#
#                       role_group_en role_group_fq_id      institution  \
# 0  Dignitary of a cathedral chapter          Q648232  Domstift Lübeck
# 1  Dignitary of a cathedral chapter          Q648232  Domstift Lübeck
# 2  Dignitary of a cathedral chapter          Q648232  Domstift Lübeck
# 3     Cleric of a cathedral chapter          Q648226  Domstift Lübeck
# 4     Cleric of a cathedral chapter          Q648226  Domstift Lübeck
#
#    institution_id diocese diocese_id date_begin date_end  date_sort_key  GND  \
# 0           676.0     NaN        NaN       1160     1177        1160150  NaN
# 1           676.0     NaN        NaN       1163     1177        1163150  NaN
# 2           676.0     NaN        NaN       1170     1177        1170150  NaN
# 3           676.0     NaN        NaN       1170      NaN        1170150  NaN
# 4           676.0     NaN        NaN       1170      NaN        1170150  NaN
#
#    GSN FactGrid
# 0  NaN  Q727495
# 1  NaN  Q727662
# 2  NaN  Q725483
# 3  NaN  Q725674
# 4  NaN  Q725658

# %% [markdown]
# # Download data from factgrid
#
# If any of the following requests to factgrid fail, try re running the cells.

# %%
url = 'https://database.factgrid.de/sparql'
query = (
    """SELECT ?item ?gsn WHERE {
  # ?item wdt:P471 ?gsn
}
"""
)
# SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }

# make request: 
r = requests.get(url, params={'query': query}, headers={"Accept": "application/json"})
data = r.json()
factgrid_institution_df = pd.json_normalize(data['results']['bindings'])

len(factgrid_institution_df)
# Out:
# 272

# %%
url = 'https://database.factgrid.de/sparql'
query = (
"""
SELECT ?item ?wiagid ?label ?alternative WHERE {
  # ?item wdt:P2/wdt:P3* wd:Q164535.
  #?item schema:description ?itemDesc.
  # ?item rdfs:label ?label.
  OPTIONAL {?item schema:description ?itemDesc.}
  OPTIONAL {?item skos:altLabel ?alternative. }
  OPTIONAL {?item wdt:P601 ?wiagid.}
  FILTER(LANG(?label) in ("en", "de"))
}
"""
)


# version 2
# SELECT ?item ?wiagid (group_concat(DISTINCT ?label; separator=',') as ?labels) (group_concat(DISTINCT ?itemDesc; separator=',') as ?itemDescs) (group_concat(DISTINCT ?alternative ; separator=',') as ?alternatives) WHERE {
#   ?item wdt:P2/wdt:P3* wd:Q164535.
#   ?item schema:description ?itemDesc.
#   ?item rdfs:label ?label.
#   OPTIONAL {?item schema:description ?itemDesc.}
#   OPTIONAL {?item skos:altLabel ?alternative. }
#   OPTIONAL {?item wdt:P601 ?wiagid.}
#   FILTER(LANG(?label) in ("en", "de"))
# }
# GROUP BY ?item ?wiagid

# SELECT ?item ?wiagid WHERE {
#   ?item wdt:P2/wdt:P3* wd:Q164535.
#   ?item wdt:P601 ?wiagid
# }
# SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }

# make request: 
r = requests.get(url, params={'query': query}, headers={"Accept": "application/json"})
data = r.json()
factgrid_diocese_df = pd.json_normalize(data['results']['bindings'])

len(factgrid_diocese_df)
# Out:
# 1280

# %%
url = 'https://database.factgrid.de/sparql'
query = (
"""
SELECT ?item ?label WHERE {
  # ?item wdt:P2 wd:Q257052.
  # ?item rdfs:label ?label.
  FILTER(LANG(?label) in ("de"))
}
"""
)

r = requests.get(url, params={'query': query}, headers={"Accept": "application/json"})
data = r.json()
factgrid_inst_roles_df = pd.json_normalize(data['results']['bindings'])

len(factgrid_inst_roles_df)
# Out:
# 4354

# %% [markdown]
# # Clean Factgrid data

# %%
# extract out q id
def extract_qid(df, column):
    df[column] = df[column].map(lambda x: x.strip('https://database.factgrid.de/entity/'))
 
#factgrid_df['item.value'] = factgrid_df['item.value'].map(lambda x: x.strip('https://database.factgrid.de/entity/'))

# drop irrelevant columns
def drop_type_columns(df):
    df.drop(columns=[column for column in df.columns if column.endswith('type')], inplace=True)
    df.drop(columns=[column for column in df.columns if column.endswith('xml:lang')], inplace=True)

# %%
extract_qid(factgrid_institution_df, 'item.value')
extract_qid(factgrid_diocese_df, 'item.value')
extract_qid(factgrid_inst_roles_df, 'item.value')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'item.value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 2
#       1 extract_qid(factgrid_institution_df, 'item.value')
# ----> 2 extract_qid(factgrid_diocese_df, 'item.value')
#       3 extract_qid(factgrid_inst_roles_df, 'item.value')
#
# Cell In[82], line 3, in extract_qid(df, column)
#       2 def extract_qid(df, column):
# ----> 3     df[column] = df[column].map(lambda x: x.strip('https://database.factgrid.de/entity/'))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'item.value'

# %%
drop_type_columns(factgrid_institution_df)
drop_type_columns(factgrid_diocese_df)
drop_type_columns(factgrid_inst_roles_df)

# %%
# rename columns
factgrid_institution_df.columns = ['fg_institution_id', 'fg_gsn_id']
factgrid_diocese_df.columns = ["fg_diocese_id", "dioc_label", "dioc_alt", "dioc_wiag_id"]
factgrid_inst_roles_df.columns = ["fg_inst_role_id", "inst_role"]

# %%
# clean the diocese alts by removing BITECA and BETA entries 
factgrid_diocese_df['dioc_alt'] = factgrid_diocese_df['dioc_alt'].replace(['^BITECA.*', '^BETA.*'], '', regex=True)
factgrid_diocese_df
# set(factgrid_diocese_df['fg_alts'])
# Out:
#      fg_diocese_id                dioc_label           dioc_alt  \
# 0          Q153261               Bistum Metz
# 1          Q153261           Diocese of Metz
# 2          Q153261               Bistum Metz
# 3          Q153261           Diocese of Metz
# 4          Q153264          Bistum Straßburg  Diözese Straßburg
# ...            ...                       ...                ...
# 1275       Q395389  Archdiocese of Agrigento    Bistum Agrigent
# 1276       Q395389        Erzbistum Agrigent   Diözese Agrigent
# 1277       Q395389  Archdiocese of Agrigento   Diözese Agrigent
# 1278       Q395390         Erzbistum Catania
# 1279       Q395390    Archdiocese of Catania
#
#                     dioc_wiag_id
# 0     WIAG-Inst-DIOCGatz-062-001
# 1     WIAG-Inst-DIOCGatz-062-001
# 2     WIAG-Inst-DIOCGatz-062-001
# 3     WIAG-Inst-DIOCGatz-062-001
# 4     WIAG-Inst-DIOCGatz-068-001
# ...                          ...
# 1275                         NaN
# 1276                         NaN
# 1277                         NaN
# 1278                         NaN
# 1279                         NaN
#
# [1280 rows x 4 columns]

# %%
factgrid_institution_df['fg_gsn_id'] = pd.to_numeric(factgrid_institution_df['fg_gsn_id'], downcast='float')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fg_gsn_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 factgrid_institution_df['fg_gsn_id'] = pd.to_numeric(factgrid_institution_df['fg_gsn_id'], downcast='float')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'fg_gsn_id'

# %%
fg_gp = factgrid_institution_df.groupby('fg_gsn_id').count()
duplicate_fg_entries = factgrid_institution_df[factgrid_institution_df['fg_gsn_id'].isin(list(fg_gp[fg_gp['fg_institution_id'] > 1].index))]
duplicate_fg_entries.head()
# Out:
# Empty DataFrame
# Columns: [fg_institution_id, fg_gsn_id]
# Index: []

# %%
assert duplicate_fg_entries.empty, f"There are possible duplicates on factgrid\n.{duplicate_fg_entries}"
factgrid_institution_df = factgrid_institution_df[~factgrid_institution_df['fg_gsn_id'].isin(duplicate_fg_entries['fg_gsn_id'].to_list())]

# %%
# factgrid_institution_df.drop_duplicates(['fg_gsn_id'], inplace=True)

# %%
factgrid_institution_df.dtypes
# Out:
# fg_institution_id     object
# fg_gsn_id            float32
# dtype: object

# %%
factgrid_diocese_df.dtypes
# Out:
# fg_diocese_id    object
# dioc_label       object
# dioc_alt         object
# dioc_wiag_id     object
# dtype: object

# %%
role_all_df.dtypes
# Out:
# person_id            object
# id                    int64
# name                 object
# role_group           object
# role_group_en        object
# role_group_fq_id     object
# institution          object
# institution_id      float64
# diocese              object
# diocese_id           object
# date_begin           object
# date_end             object
# date_sort_key         int64
# GND                  object
# GSN                  object
# FactGrid             object
# dtype: object

# %%
# TODO: Find a way to query amter data directly from wiag
# url = 'https://wiag-vocab.adw-goe.de/domherr/data'
# r = requests.get(url, params={'domstift': place_name})
# data = r.json()
# person_import_df = pd.json_normalize(data['persons'])

# print(len(person_import_df))
# person_import_df.head()

# %%
factgrid_institution_df.head()
# Out:
#   item.type                                   item.value gsn.type gsn.value
# 0       uri  https://database.factgrid.de/entity/Q422286  literal       114
# 1       uri  https://database.factgrid.de/entity/Q470546  literal       119
# 2       uri  https://database.factgrid.de/entity/Q633292  literal       120
# 3       uri  https://database.factgrid.de/entity/Q633339  literal       131
# 4       uri  https://database.factgrid.de/entity/Q633346  literal       139

# %%
factgrid_diocese_df.head()
# Out:
#   fg_diocese_id        dioc_label           dioc_alt  \
# 0       Q153261       Bistum Metz
# 1       Q153261   Diocese of Metz
# 2       Q153261       Bistum Metz
# 3       Q153261   Diocese of Metz
# 4       Q153264  Bistum Straßburg  Diözese Straßburg
#
#                  dioc_wiag_id
# 0  WIAG-Inst-DIOCGatz-062-001
# 1  WIAG-Inst-DIOCGatz-062-001
# 2  WIAG-Inst-DIOCGatz-062-001
# 3  WIAG-Inst-DIOCGatz-062-001
# 4  WIAG-Inst-DIOCGatz-068-001

# %% [markdown]
# # Check for missing data

# %% [markdown]
# ## Check for missing institutions

# %%
missing_institution_on_factgrid_df = role_all_df.merge(
    factgrid_institution_df, indicator = True, how='left', left_on='institution_id', right_on='fg_gsn_id', suffixes=('_wiag', '_institute_fg')
).loc[lambda x : x['_merge']!='both']

# %%
print(len(missing_institution_on_factgrid_df))
missing_institution_on_factgrid_df.head()
# Out:
# 685
#                         person_id     id       name  \
# 29  WIAG-Pers-EPISCGatz-03024-001  80808    Bischof
# 49      WIAG-Pers-CANON-19889-001   9303  Kanoniker
# 65      WIAG-Pers-CANON-19903-001  70200    Domherr
# 77  WIAG-Pers-EPISCGatz-03475-001  80170    Bischof
# 82  WIAG-Pers-EPISCGatz-03232-001  98649    Bischof
#
#                       role_group                                role_group_en  \
# 29  Oberstes Leitungsamt Diözese                     Head of an (arch)diocese
# 49                     Amt Stift  Affiliate of a collegiate church or convent
# 65                  Amt Domstift                Cleric of a cathedral chapter
# 77  Oberstes Leitungsamt Diözese                     Head of an (arch)diocese
# 82  Oberstes Leitungsamt Diözese                     Head of an (arch)diocese
#
#    role_group_fq_id                          institution  institution_id  \
# 29          Q648236                                  NaN             NaN
# 49          Q648228  Kollegiatstift St. Peter, Bardowick           324.0
# 65          Q648226                      Domstift Verden          3487.0
# 77          Q648236                                  NaN             NaN
# 82          Q648236                                  NaN             NaN
#
#             diocese                  diocese_id date_begin date_end  \
# 29    Bistum Lübeck  WIAG-Inst-DIOCGatz-014-001       1210     1230
# 49              NaN                         NaN       1219      NaN
# 65              NaN                         NaN       1229     1231
# 77  Bistum Schwerin  WIAG-Inst-DIOCGatz-028-001       1240     1247
# 82    Bistum Olmütz  WIAG-Inst-DIOCGatz-064-001       1245     1281
#
#     date_sort_key        GND            GSN FactGrid fg_institution_id  \
# 29        1210150        NaN            NaN  Q652312               NaN
# 49        1219150        NaN            NaN  Q727542               NaN
# 65        1229150  100989101            NaN  Q727571               NaN
# 77        1240150        NaN            NaN  Q652425               NaN
# 82        1245150  104280050  060-00594-001  Q390757               NaN
#
#     fg_gsn_id     _merge
# 29        NaN  left_only
# 49        NaN  left_only
# 65        NaN  left_only
# 77        NaN  left_only
# 82        NaN  left_only

# %%
# missing_institution_on_factgrid_df[['institution', 'institution_id', 'diocese', 'diocese_id']]

# %% [markdown]
# ## Create a csv file with persons having no institution_id, diocese_id and diocese
#
# Note: the file generated by this cell is only relevant in case of incorrect entries on wiag.
#
# If this cell throws an error, please check the file `simple_null_entries_amter-{today'sd date}.csv` and check the records on wiag using the person_id from there.

# %%
missing_institution_diocese_on_factgrid_df = missing_institution_on_factgrid_df.merge(
    factgrid_diocese_df, indicator = '_second_merge', how='left', left_on='diocese_id', right_on='dioc_wiag_id', suffixes=('_wiag', '_dioc_fg')
).loc[lambda x : x['_second_merge']!='both']
missing_institution_diocese_on_factgrid_df.drop(['_merge','_second_merge'], axis=1, inplace=True)
null_entries = missing_institution_diocese_on_factgrid_df[missing_institution_diocese_on_factgrid_df[['institution_id', 'diocese_id', 'diocese']].isna().all(axis=1)]
null_entries = null_entries[null_entries['name'] != 'Kardinal'].sort_values('person_id')

# 4312 to 7979 should be removed
null_entries = null_entries[null_entries.person_id.str.contains('[0-7][0-9]{4}-[0-9]{3}$', regex=True)]
if not null_entries.empty:
    null_entries.to_csv(os.path.join(output_path, f'simple_null_entries_amter-{today_string}.csv'), sep=';')
assert len(null_entries) == 0

# %% [markdown]
# ## Add diocese information from factgrid
#
# Diocese is matched by 3 queries between wiag and factgrid. They are applied in the following priority. If a higher priority query find a match, the following query does nothing:
# * wiag id (wiag) => wiag id (factgrid)
# * diocese name (wiag) => diocese label (factgrid)
# * diocese name (wiag) => diocese alt label (factgrid)

# %%
# lookup for the diocese by the diocese_id, then diocese labels, then diocese alts
def join_dioceses(input_df):
    rows = []
    for _, row in input_df.iterrows():
        search_row = pd.Series({'fg_diocese_id':None, 'dioc_label':None, 'dioc_alt':None, 'dioc_wiag_id':None})

        # NOTE: in the following three code blocks only the query changes.
        # this could be refactored somehow without running the query when defining it
        if not search_row['fg_diocese_id']:
            query = factgrid_diocese_df[factgrid_diocese_df['dioc_wiag_id'] == row['diocese_id']]
            if not query.empty:
                search_row = query.head(1).squeeze(axis=0)
    
        if not search_row['fg_diocese_id']:
            query = factgrid_diocese_df[factgrid_diocese_df['dioc_label'] == row['diocese']]
            if not query.empty:
                search_row = query.head(1).squeeze(axis=0)
    
        if not search_row['fg_diocese_id']:
            query = factgrid_diocese_df[factgrid_diocese_df['dioc_alt'] == row['diocese']]
            if not query.empty:
                search_row = query.head(1).squeeze(axis=0)
        rows.append(row.combine_first(search_row))
    
    dioc_joined_df = pd.DataFrame(rows)
    dioc_joined_df = dioc_joined_df[[*input_df.columns, *factgrid_diocese_df.columns]]
    
    return dioc_joined_df
dioc_joined_df = join_dioceses(missing_institution_on_factgrid_df)
print(len(dioc_joined_df))
dioc_joined_df.head()
# Out:
# 685
#                         person_id     id       name  \
# 29  WIAG-Pers-EPISCGatz-03024-001  80808    Bischof
# 49      WIAG-Pers-CANON-19889-001   9303  Kanoniker
# 65      WIAG-Pers-CANON-19903-001  70200    Domherr
# 77  WIAG-Pers-EPISCGatz-03475-001  80170    Bischof
# 82  WIAG-Pers-EPISCGatz-03232-001  98649    Bischof
#
#                       role_group                                role_group_en  \
# 29  Oberstes Leitungsamt Diözese                     Head of an (arch)diocese
# 49                     Amt Stift  Affiliate of a collegiate church or convent
# 65                  Amt Domstift                Cleric of a cathedral chapter
# 77  Oberstes Leitungsamt Diözese                     Head of an (arch)diocese
# 82  Oberstes Leitungsamt Diözese                     Head of an (arch)diocese
#
#    role_group_fq_id                          institution  institution_id  \
# 29          Q648236                                  NaN             NaN
# 49          Q648228  Kollegiatstift St. Peter, Bardowick           324.0
# 65          Q648226                      Domstift Verden          3487.0
# 77          Q648236                                  NaN             NaN
# 82          Q648236                                  NaN             NaN
#
#             diocese                  diocese_id  ...        GND  \
# 29    Bistum Lübeck  WIAG-Inst-DIOCGatz-014-001  ...        NaN
# 49              NaN                         NaN  ...        NaN
# 65              NaN                         NaN  ...  100989101
# 77  Bistum Schwerin  WIAG-Inst-DIOCGatz-028-001  ...        NaN
# 82    Bistum Olmütz  WIAG-Inst-DIOCGatz-064-001  ...  104280050
#
#               GSN  FactGrid fg_institution_id fg_gsn_id     _merge  \
# 29            NaN   Q652312               NaN       NaN  left_only
# 49            NaN   Q727542               NaN       NaN  left_only
# 65            NaN   Q727571               NaN       NaN  left_only
# 77            NaN   Q652425               NaN       NaN  left_only
# 82  060-00594-001   Q390757               NaN       NaN  left_only
#
#     fg_diocese_id       dioc_label          dioc_alt  \
# 29        Q153228    Bistum Lübeck    Diözese Lübeck
# 49           None             None              None
# 65           None             None              None
# 77        Q153242  Bistum Schwerin  Diözese Schwerin
# 82        Q153262    Bistum Olmütz    Diözese Olmütz
#
#                   dioc_wiag_id
# 29  WIAG-Inst-DIOCGatz-014-001
# 49                        None
# 65                        None
# 77  WIAG-Inst-DIOCGatz-028-001
# 82  WIAG-Inst-DIOCGatz-064-001
#
# [5 rows x 23 columns]

# %%
missing_institution_diocese_on_factgrid_df = dioc_joined_df[dioc_joined_df['fg_diocese_id'].isna()]

# %%
# missing_institution_diocese_on_factgrid_df.drop(['_merge'], axis=1, inplace=True)

# %%
# missing_institution_diocese_on_factgrid_df[missing_institution_diocese_on_factgrid_df.person_id.str.contains('[89][0-9]{4}-[0-9]{3}$', regex=True)]

# %% [markdown]
# ## Create a csv file with missing ids for institution or diocese

# %%
# null_entries = missing_institution_diocese_on_factgrid_df[missing_institution_diocese_on_factgrid_df['institution_id'].isnull()][missing_institution_diocese_on_factgrid_df['diocese_id'].isnull()]
null_entries = missing_institution_diocese_on_factgrid_df[missing_institution_diocese_on_factgrid_df['role_group'] != 'Kardinal'].sort_values('person_id')
null_entries = null_entries[null_entries['role_group'] != 'Kurienamt']
null_entries = null_entries[null_entries['role_group'] != 'Papst']
null_entries = null_entries.sort_values(['diocese', 'institution'])

# remove pr entries. why? TODO: ask barbara for confirmation
# null_entries = null_entries[null_entries.person_id.str.contains('[0-7][0-9]{4}-[0-9]{3}$', regex=True)]
null_entries[null_entries.columns[:-7]].to_csv(os.path.join(output_path, f'missing_amter-{today_string}.csv'), sep=';')
null_entries
# Out:
#                           person_id      id                    name  \
# 1986  WIAG-Pers-EPISCGatz-05361-001  132324                  Propst
# 952   WIAG-Pers-EPISCGatz-03223-001  109691                     Abt
# 1731      WIAG-Pers-CANON-19465-001  133498         Vikar, Anwärter
# 1431      WIAG-Pers-CANON-19513-001   18153         Vikar, Anwärter
# 982       WIAG-Pers-CANON-19943-001  100237  Providierter Kanoniker
# ...                             ...     ...                     ...
# 1344      WIAG-Pers-CANON-19604-001  112601                  Propst
# 2026  WIAG-Pers-EPISCGatz-20091-001  119117               Kanoniker
# 1607      WIAG-Pers-CANON-19789-001  107165                  Propst
# 1229  WIAG-Pers-EPISCGatz-05574-001  100339         Vikar, Anwärter
# 910       WIAG-Pers-CANON-18961-001   71485                   Vikar
#
#                         role_group  \
# 1986  Oberstes Leitungsamt Kloster
# 952   Oberstes Leitungsamt Kloster
# 1731                     Amt Stift
# 1431                     Amt Stift
# 982                      Amt Stift
# ...                            ...
# 1344  Oberstes Leitungsamt Kloster
# 2026                     Amt Stift
# 1607  Oberstes Leitungsamt Kloster
# 1229                     Amt Stift
# 910                      Amt Stift
#
#                                     role_group_en role_group_fq_id  \
# 1986  Monastery member with a leadership position          Q648233
# 952   Monastery member with a leadership position          Q648233
# 1731  Affiliate of a collegiate church or convent          Q648228
# 1431  Affiliate of a collegiate church or convent          Q648228
# 982   Affiliate of a collegiate church or convent          Q648228
# ...                                           ...              ...
# 1344  Monastery member with a leadership position          Q648233
# 2026  Affiliate of a collegiate church or convent          Q648228
# 1607  Monastery member with a leadership position          Q648233
# 1229  Affiliate of a collegiate church or convent          Q648228
# 910   Affiliate of a collegiate church or convent          Q648228
#
#                                             institution  institution_id  \
# 1986           Augustinerchorherrenstift Neuwerk, Halle          3613.0
# 952   Benediktiner-, dann Prämonstratenserabtei St. ...          7106.0
# 1731                 Benediktinerabtei St. Maria, Stade           891.0
# 1431                 Benediktinerabtei St. Maria, Stade           891.0
# 982   Benediktinerabtei, dann Kollegiatstift St. Ser...          3234.0
# ...                                                 ...             ...
# 1344                Kollegiatstift St. Willehad, Bremen           344.0
# 2026                Kollegiatstift St. Willehad, Bremen           344.0
# 1607        Minderstift St. Johannes Baptista, Lüneburg           845.0
# 1229        Minderstift St. Johannes Baptista, Lüneburg           845.0
# 910   Zisterzienserinnenkloster Rinteln, später Bene...          3577.0
#
#      diocese diocese_id  ...         GND            GSN  FactGrid  \
# 1986     NaN        NaN  ...  1149618302            NaN   Q654377
# 952      NaN        NaN  ...  1062751981  305-00050-001   Q655092
# 1731     NaN        NaN  ...         NaN            NaN   Q726499
# 1431     NaN        NaN  ...         NaN            NaN   Q726609
# 982      NaN        NaN  ...         NaN            NaN   Q727685
# ...      ...        ...  ...         ...            ...       ...
# 1344     NaN        NaN  ...         NaN            NaN   Q726822
# 2026     NaN        NaN  ...   137406495            NaN   Q654018
# 1607     NaN        NaN  ...         NaN            NaN   Q727298
# 1229     NaN        NaN  ...  1150819278  305-00228-001   Q656098
# 910      NaN        NaN  ...         NaN            NaN   Q725626
#
#      fg_institution_id fg_gsn_id     _merge  fg_diocese_id  dioc_label  \
# 1986               NaN       NaN  left_only           None        None
# 952                NaN       NaN  left_only           None        None
# 1731               NaN       NaN  left_only           None        None
# 1431               NaN       NaN  left_only           None        None
# 982                NaN       NaN  left_only           None        None
# ...                ...       ...        ...            ...         ...
# 1344               NaN       NaN  left_only           None        None
# 2026               NaN       NaN  left_only           None        None
# 1607               NaN       NaN  left_only           None        None
# 1229               NaN       NaN  left_only           None        None
# 910                NaN       NaN  left_only           None        None
#
#      dioc_alt dioc_wiag_id
# 1986     None         None
# 952      None         None
# 1731     None         None
# 1431     None         None
# 982      None         None
# ...       ...          ...
# 1344     None         None
# 2026     None         None
# 1607     None         None
# 1229     None         None
# 910      None         None
#
# [474 rows x 23 columns]

# %% [markdown]
# # Create the missing institutions on factgrid here

# %%
# get all institutions with a kloster id 
missing_kloester_df = null_entries[
    ~(pd.isna(null_entries['institution_id']) |
    pd.isna(null_entries['institution']))
][null_entries.columns[:-7]]
len(missing_kloester_df)
# Out:
# 474

# %% [markdown]
# Creates a file with the name institution_creation_<date>.csv
#
# Fill in the empty columns of the file and then use the file on quickstatements.

# %%
create_institution_factgrid_df = missing_kloester_df[['institution', 'institution_id']].copy()
create_institution_factgrid_df.columns = ['Lde', 'P471']
create_institution_factgrid_df['P471'] = create_institution_factgrid_df['P471'].astype(int)
create_institution_factgrid_df.insert(0, column='qid', value='')
create_institution_factgrid_df.insert(2, column='Les', value='')
create_institution_factgrid_df.insert(2, column='Lfr', value='')
create_institution_factgrid_df.insert(2, column='Len', value='')
create_institution_factgrid_df.insert(6, column='Den', value='')
create_institution_factgrid_df.insert(6, column='Dde', value='')
create_institution_factgrid_df['P131'] = 'Q153178'
create_institution_factgrid_df.set_index('qid')
create_institution_factgrid_df.to_csv(os.path.join(output_path, f'institution_creation_{today_string}.csv'), index=False)
create_institution_factgrid_df
# Out:
#      qid                                                Lde Len Lfr Les  P471  \
# 1986               Augustinerchorherrenstift Neuwerk, Halle              3613
# 952       Benediktiner-, dann Prämonstratenserabtei St. ...              7106
# 1731                     Benediktinerabtei St. Maria, Stade               891
# 1431                     Benediktinerabtei St. Maria, Stade               891
# 982       Benediktinerabtei, dann Kollegiatstift St. Ser...              3234
# ...   ..                                                ...  ..  ..  ..   ...
# 1344                    Kollegiatstift St. Willehad, Bremen               344
# 2026                    Kollegiatstift St. Willehad, Bremen               344
# 1607            Minderstift St. Johannes Baptista, Lüneburg               845
# 1229            Minderstift St. Johannes Baptista, Lüneburg               845
# 910       Zisterzienserinnenkloster Rinteln, später Bene...              3577
#
#      Dde Den     P131
# 1986          Q153178
# 952           Q153178
# 1731          Q153178
# 1431          Q153178
# 982           Q153178
# ...   ..  ..      ...
# 1344          Q153178
# 2026          Q153178
# 1607          Q153178
# 1229          Q153178
# 910           Q153178
#
# [474 rows x 9 columns]

# %%
# for _, row in missing_kloester_df.iterrows():
#     print(row)
#     print("CREATE")
#     # Labels
#     name = row['institution']
#     name = f'"{name}"'
#     print('\t'.join(["LAST", "Lde", name]))
#     print('\t'.join(["LAST", "Len", name]))
#     print('\t'.join(["LAST", "Lfr", name]))
#     print('\t'.join(["LAST", "Les", name]))

#     # klosterdatenbank
#     kloster_id = str(int(row['institution_id']))
#     print('\t'.join(["LAST", "P471", kloster_id]))

#     # research project
#     print('\t'.join(["LAST", "P131", 'Q153178']))

#     # p1100 do we need it for institution? I don't think so.
#     # print('\t'.join(["LAST", "P1100", f'off_gsn{kloster_id}']))

#     # query data from klosterdatenbank
#     # https://api.gs.sub.uni-goettingen.de/v1/monastery/3346/json
#     # r = requests.get(f'https://api.gs.sub.uni-goettingen.de/v1/monastery/{kloster_id}', headers={"Accept": "application/json"})
#     # data = r.json()
#     # del data["literature"]
#     # del data["persons"]
#     # print(json.dumps(data, sort_keys=True, indent=4))
    
#     break

# %% [markdown]
# ### To continue below your csv files should be empty. The check below ensures that.

# %%
assert len(create_institution_factgrid_df) == 0, "Create the entries on factgrid before continuing and then re run all code cells from the beginning."
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 assert len(create_institution_factgrid_df) == 0, "Create the entries on factgrid before continuing and then re run all code cells from the beginning."
#
# AssertionError: Create the entries on factgrid before continuing and then re run all code cells from the beginning.

# %%
# TODO: sent ouput to file instead of stdout

# for _, row in null_entries[null_entries['diocese'].notnull()][['diocese', 'diocese_id']].iterrows():
#     print("CREATE")
#     print('\t'.join(['LAST', 'Lde', f'"{row["diocese"]}"']))
#     print('\t'.join(['LAST', 'P2', 'Q153166']))

#     print('\t'.join(['LAST', 'P131', 'Q153178']))
#     if type(row['diocese_id']) == str:
#         print('\t'.join(['LAST', 'P601', f'"{row["diocese_id"]}"']))

# %%
# missing_institution_diocese_on_factgrid_df.to_csv('no_institution_or_dioc_on_fg_bamberg.csv', sep=';')

# %% [markdown]
# # Add factgrid information

# %% [markdown]
# ## Add institution factgrid id

# %%
institution_joined_df = role_all_df.merge(
    factgrid_institution_df, how='left', left_on='institution_id', right_on='fg_gsn_id', suffixes=('_wiag', '_institute_fg')
)
print(len(institution_joined_df))
institution_joined_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10356\2077216027.py in ?()
# ----> 1 institution_joined_df = role_all_df.merge(
#       2     factgrid_institution_df, how='left', left_on='institution_id', right_on='fg_gsn_id', suffixes=('_wiag', '_institute_fg')
#       3 )
#       4 print(len(institution_joined_df))
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10815         validate: MergeValidate | None = None,
#   10816     ) -> DataFrame:
#   10817         from pandas.core.reshape.merge import merge
#   10818
# > 10819         return merge(
#   10820             self,
#   10821             right,
#   10822             how=how,
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1293                         # Then we're either Hashable or a wrong-length arraylike,
#    1294                         #  the latter of which will raise
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#    1300                             right_keys.append(right.index._values)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1906             values = self.xs(key, axis=other_axes[0])._values
#    1907         elif self._is_level_reference(key, axis=axis):
#    1908             values = self.axes[axis].get_level_values(key)._values
#    1909         else:
# -> 1910             raise KeyError(key)
#    1911
#    1912         # Check for duplicates
#    1913         if values.ndim > 1:
#
# KeyError: 'fg_gsn_id'

# %%
assert len(role_all_df) == len(institution_joined_df), "There may be duplicates on factgrid"

# %% [markdown]
# ## Add diocese factgrid id

# %%
dioc_joined_df = join_dioceses(institution_joined_df)
print(len(dioc_joined_df))
dioc_joined_df.head()
# Out:
# 31472
#                        person_id      id               name  \
# 0  WIAG-Pers-EPISCGatz-03848-001  124071            Domherr
# 1  WIAG-Pers-EPISCGatz-03848-001  124073            Bischof
# 2  WIAG-Pers-EPISCGatz-03848-001  124075                Abt
# 3  WIAG-Pers-EPISCGatz-03848-001  124077                Abt
# 4  WIAG-Pers-EPISCGatz-03858-001  124065  Ernannter Bischof
#
#                      role_group                                role_group_en  \
# 0                  Amt Domstift                Cleric of a cathedral chapter
# 1  Oberstes Leitungsamt Diözese                     Head of an (arch)diocese
# 2  Oberstes Leitungsamt Kloster  Monastery member with a leadership position
# 3  Oberstes Leitungsamt Kloster  Monastery member with a leadership position
# 4  Oberstes Leitungsamt Diözese                     Head of an (arch)diocese
#
#   role_group_fq_id                     institution  institution_id  \
# 0          Q648226               Domstift Augsburg          3498.0
# 1          Q648236                             NaN             NaN
# 2          Q648233     Benediktinerkloster Kempten         60182.0
# 3          Q648233  Benediktinerkloster Ottobeuren         60305.0
# 4          Q648236                             NaN             NaN
#
#            diocese                  diocese_id  ... date_sort_key        GND  \
# 0              NaN                         NaN  ...        909210  118625284
# 1  Bistum Augsburg  WIAG-Inst-DIOCGatz-001-001  ...        923150  118625284
# 2              NaN                         NaN  ...        948100  118625284
# 3              NaN                         NaN  ...        972150  118625284
# 4  Bistum Augsburg  WIAG-Inst-DIOCGatz-001-001  ...       1077150  13805746X
#
#              GSN FactGrid fg_institution_id fg_gsn_id fg_diocese_id  \
# 0  059-01621-001  Q653546           Q898020    3498.0          None
# 1  059-01621-001  Q653546               NaN       NaN       Q153179
# 2  059-01621-001  Q653546           Q266876   60182.0          None
# 3  059-01621-001  Q653546               NaN       NaN          None
# 4  050-06892-001  Q653421               NaN       NaN       Q153179
#
#         dioc_label          dioc_alt                dioc_wiag_id
# 0             None              None                        None
# 1  Bistum Augsburg  Diözese Augsburg  WIAG-Inst-DIOCGatz-001-001
# 2             None              None                        None
# 3             None              None                        None
# 4  Bistum Augsburg  Diözese Augsburg  WIAG-Inst-DIOCGatz-001-001
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Add role factgrid id
# Note: This role does not include the institution information. ie, it adds factgrid ids for roles like 'archbishop' and not 'archbishop of trier'
#
# The part of the script below could be used to create quickstatements for career statements.

# %%
print(len(wiag_roles_df))
wiag_roles_df.head()
#wiag_roles_df[wiag_roles_df['name'] == '']
# Out:
# 263
#    id note                             name comment  gs_reg_id generic_term  \
# 0   1  NaN                     Titularkönig     NaN        NaN          NaN
# 1   2  NaN                       Abtbischof     NaN        NaN          NaN
# 2   3  NaN        Administrator des Bistums     NaN        NaN          NaN
# 3   4  NaN     Administrator des Erzbistums     NaN        NaN          NaN
# 4   5  NaN  Administrator des Fürstbischofs     NaN        NaN          NaN
#
#   plural                                         definition role_gp_fg_id  \
# 0    NaN                                                NaN           NaN
# 1    NaN                                                NaN       Q648236
# 2    NaN  Ein Bistumsadministrator (auch: Diözesanadmini...       Q648236
# 3    NaN                                                NaN       Q648236
# 4    NaN  Ein Bistumsadministrator (auch: Diözesanadmini...       Q648236
#
#      gender lang  role_group_id       r_id  item_id  r_note  authority_id  \
# 0  männlich   de           32.0        NaN      NaN     NaN           NaN
# 1  männlich   de           33.0        NaN      NaN     NaN           NaN
# 2  männlich   de           33.0  1298102.0      3.0     NaN          42.0
# 3  männlich   de           33.0  1298104.0      4.0     NaN          42.0
# 4  männlich   de           33.0  1298982.0      5.0     NaN          42.0
#
#   role_fg_id  r_comment
# 0        NaN        NaN
# 1        NaN        NaN
# 2    Q902170        NaN
# 3    Q902170        NaN
# 4    Q902170        NaN

# %%
joined_df = dioc_joined_df.merge(
    wiag_roles_df[['name', 'role_fg_id']], how='left', left_on='name', right_on='name', suffixes=('_wiag', '_institute_fg')
)
print(len(joined_df))
joined_df.head()
# Out:
# 31695
#                        person_id      id               name  \
# 0  WIAG-Pers-EPISCGatz-03848-001  124071            Domherr
# 1  WIAG-Pers-EPISCGatz-03848-001  124073            Bischof
# 2  WIAG-Pers-EPISCGatz-03848-001  124075                Abt
# 3  WIAG-Pers-EPISCGatz-03848-001  124077                Abt
# 4  WIAG-Pers-EPISCGatz-03858-001  124065  Ernannter Bischof
#
#                      role_group                                role_group_en  \
# 0                  Amt Domstift                Cleric of a cathedral chapter
# 1  Oberstes Leitungsamt Diözese                     Head of an (arch)diocese
# 2  Oberstes Leitungsamt Kloster  Monastery member with a leadership position
# 3  Oberstes Leitungsamt Kloster  Monastery member with a leadership position
# 4  Oberstes Leitungsamt Diözese                     Head of an (arch)diocese
#
#   role_group_fq_id                     institution  institution_id  \
# 0          Q648226               Domstift Augsburg          3498.0
# 1          Q648236                             NaN             NaN
# 2          Q648233     Benediktinerkloster Kempten         60182.0
# 3          Q648233  Benediktinerkloster Ottobeuren         60305.0
# 4          Q648236                             NaN             NaN
#
#            diocese                  diocese_id  ...        GND            GSN  \
# 0              NaN                         NaN  ...  118625284  059-01621-001
# 1  Bistum Augsburg  WIAG-Inst-DIOCGatz-001-001  ...  118625284  059-01621-001
# 2              NaN                         NaN  ...  118625284  059-01621-001
# 3              NaN                         NaN  ...  118625284  059-01621-001
# 4  Bistum Augsburg  WIAG-Inst-DIOCGatz-001-001  ...  13805746X  050-06892-001
#
#    FactGrid fg_institution_id fg_gsn_id fg_diocese_id       dioc_label  \
# 0   Q653546           Q898020    3498.0          None             None
# 1   Q653546               NaN       NaN       Q153179  Bistum Augsburg
# 2   Q653546           Q266876   60182.0          None             None
# 3   Q653546               NaN       NaN          None             None
# 4   Q653421               NaN       NaN       Q153179  Bistum Augsburg
#
#            dioc_alt                dioc_wiag_id role_fg_id
# 0              None                        None     Q38837
# 1  Diözese Augsburg  WIAG-Inst-DIOCGatz-001-001     Q38809
# 2              None                        None     Q38954
# 3              None                        None     Q38954
# 4  Diözese Augsburg  WIAG-Inst-DIOCGatz-001-001    Q902184
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Ignore all Kanonikatsbewerber and Vikariatsbewerber offices

# %%
#
joined_df = joined_df[~joined_df['name'].isin(
    ['Vikariatsbewerber', 
     'Kanonikatsbewerber']
)]

# %% [markdown]
# ## The output below should be empty. The cell after the next one will throw an error if it's not the case

# %%
missing_roles_df = joined_df[joined_df['role_fg_id'].isna()]
missing_roles_df.head()
# Out:
#                         person_id      id                          name  \
# 33      WIAG-Pers-CANON-13216-001   18373        Propst und Archidiakon
# 50      WIAG-Pers-CANON-49220-001  109435                   Domkämmerer
# 61  WIAG-Pers-EPISCGatz-02684-001  124663  Generalvikar des Erzbischofs
# 62  WIAG-Pers-EPISCGatz-02684-001  124665      Offizial des Erzbischofs
# 66  WIAG-Pers-EPISCGatz-02684-001  124673        Domthesaurar, Anwärter
#
#               role_group                     role_group_en role_group_fq_id  \
# 33   Leitungsamt Diözese          Head of an (arch)diocese          Q648236
# 50  Leitungsamt Domstift  Dignitary of a cathedral chapter          Q648232
# 61   Leitungsamt Diözese          Head of an (arch)diocese          Q648236
# 62   Leitungsamt Diözese          Head of an (arch)diocese          Q648236
# 66  Leitungsamt Domstift  Dignitary of a cathedral chapter          Q648232
#
#                                           institution  institution_id  \
# 33  Benediktinerkloster Ansbach, später Kollegiats...          1015.0
# 50                                    Domstift Speyer          3489.0
# 61                                                NaN             NaN
# 62                                                NaN             NaN
# 66                                  Domstift Augsburg          3498.0
#
#                diocese                  diocese_id  ...         GND  GSN  \
# 33                 NaN                         NaN  ...         NaN  NaN
# 50                 NaN                         NaN  ...  1038267439  NaN
# 61  Erzbistum Salzburg  WIAG-Inst-DIOCGatz-045-001  ...   140745025  NaN
# 62  Erzbistum Salzburg  WIAG-Inst-DIOCGatz-045-001  ...   140745025  NaN
# 66                 NaN                         NaN  ...   140745025  NaN
#
#     FactGrid fg_institution_id fg_gsn_id fg_diocese_id          dioc_label  \
# 33   Q648997           Q400534    1015.0          None                None
# 50   Q700918           Q898039    3489.0          None                None
# 61   Q651525               NaN       NaN       Q153249  Erzbistum Salzburg
# 62   Q651525               NaN       NaN       Q153249  Erzbistum Salzburg
# 66   Q651525           Q898020    3498.0          None                None
#
#            dioc_alt                dioc_wiag_id role_fg_id
# 33             None                        None        NaN
# 50             None                        None        NaN
# 61  Bistum Salzburg  WIAG-Inst-DIOCGatz-045-001        NaN
# 62  Bistum Salzburg  WIAG-Inst-DIOCGatz-045-001        NaN
# 66             None                        None        NaN
#
# [5 rows x 23 columns]

# %%
wiag_roles_df[wiag_roles_df['name'].str.contains('Domp.*')]
# Out:
#         id note                    name comment  gs_reg_id generic_term  \
# 149    149  NaN     Dompropst, Anwärter     NaN    10150.0    Dompropst
# 150    150  NaN               Dompropst     NaN    10150.0       Propst
# 151    151  NaN             Domprediger     NaN    13040.0     Prediger
# 152    152  NaN             Dompfortner     NaN        NaN     Pfortner
# 191    190  NaN  Providierter Dompropst     NaN    10150.0    Dompropst
# 252    250  NaN                Domprior     NaN    10140.0          NaN
# 262  60700  NaN              Dompfarrer     NaN        NaN          NaN
#
#                      plural definition role_gp_fg_id    gender lang  \
# 149    Dompröpste, Anwärter        NaN       Q648232  männlich   de
# 150              Dompröpste        NaN       Q648232  männlich   de
# 151             Domprediger        NaN       Q648226  männlich   de
# 152             Dompfortner        NaN       Q648226  männlich   de
# 191  Providierte Dompröpste        NaN       Q648232  männlich   de
# 252              Domprioren        NaN       Q648232  männlich   de
# 262              Dompfarrer        NaN           NaN  männlich   de
#
#      role_group_id       r_id  item_id  r_note  authority_id role_fg_id  \
# 149           41.0  1298124.0    149.0     NaN          42.0    Q902178
# 150           41.0  1102327.0    150.0     NaN          42.0     Q38842
# 151           42.0  1102335.0    151.0     NaN          42.0     Q38841
# 152           42.0        NaN      NaN     NaN           NaN        NaN
# 191           41.0        NaN      NaN     NaN           NaN        NaN
# 252           41.0        NaN      NaN     NaN           NaN        NaN
# 262           42.0  1298122.0  60700.0     NaN          42.0    Q902177
#
#      r_comment
# 149        NaN
# 150        NaN
# 151        NaN
# 152        NaN
# 191        NaN
# 252        NaN
# 262        NaN

# %%
missing_roles = joined_df[joined_df['role_fg_id'].isna()]['name'].unique()
print(len(missing_roles))
missing_roles
# Out:
# 128
# array(['Propst und Archidiakon', 'Domkämmerer',
#        'Generalvikar des Erzbischofs', 'Offizial des Erzbischofs',
#        'Domthesaurar, Anwärter', 'Thesaurar', 'Providierter Propst',
#        'Domscholaster, Anwärter', 'Kaplan', 'Dechant (Prag)',
#        'Fürsterzbischof', 'Stiftsherr', 'Domprior', 'Altarist',
#        'Bischöflicher Offizial', 'Gewählter Koadjutor des Bischofs',
#        'Domdechant', 'Ernannter Erzbischof',
#        'Providierter und konfirmierter Bischof', 'Providierter Dompropst',
#        'Vizedominus', 'Generaloffizial', 'Providierter Domvikar',
#        'Dekan, Anwärter', 'Lektor', 'Domdekan, Anwärter',
#        'Archidiakon (Schleswig)', 'Evangelischer Administrator',
#        'Bischofskandidat', 'Offizial des Bischofs',
#        'Koadjutor des Fürstpropstes', 'Fürstpropst',
#        'Koadjutor des Fürstabtes', 'Koadjutor des Propstes',
#        'Domchorbischof', 'Apostolischer Vikar', 'Gegenbischof', 'Viztum',
#        'Domküster', 'Kanonikatsanwärter', 'Vikarieanwärter',
#        'Dompfortner', 'Propst (Schleswig)',
#        'Generalvikar des Kurfürst-Erzbischofs', 'Kommendatarabt',
#        'Chorbischof', 'Vizedominus, Anwärter', 'Scholaster, Anwärter',
#        'Providierter Vikar', 'Postulierter Bischof', 'Domkeppler',
#        'Kollektor', 'Metropolitanvikar', 'Domkellnereiassessor', 'Novize',
#        'Domkameral', 'Präbendat', 'Chorherr', 'Plebanatsbewerber',
#        'Pleban', 'Domsubdekan', 'Domunterscholaster', 'Domunterküster',
#        'Unterküster', 'Domkustos, Anwärter', 'Propsteibewerber',
#        'Designierter Bischof', 'Graf', 'Kämmerer', 'Kanonikeranwärter',
#        'Archidiakon, Anwärter', 'Herzog', 'Kellermeister', 'Hochmeister',
#        'Gewählter Kurfürst-Erzbischof', 'Koadministrator',
#        'Ernannter Weihbischof', 'Providierter Domscholaster',
#        'Providierter Domdekan', 'Providierter Domkantor', 'Vizedekan',
#        'Providierter Thesaurar', 'Providierter Domkellermeister', 'Vogt',
#        'Landgraf', 'Schreiber', 'Propsteianwärter', 'Siegler',
#        'Prokurator', 'Sekretär', 'Domsyndikus',
#        'Erzbischöflicher Notar und Sekretär',
#        'Erzbischöflicher Protonotar', 'Erzbischöflicher Prokurator',
#        'Erzbischöflicher Kämmerer', 'Priestermönch',
#        'Erzbischöflicher Provisor', 'Päpstlicher Kämmerer',
#        'Päpstlicher Notar', 'Syndikus', 'Cancellar', 'Vicedominus',
#        'Erwählter Bischof', 'Dombursar', 'Benefiziatbewerber', 'Pastor',
#        'Offiziant', 'Dechant', 'Siegler und Generalvikar', 'Fraterherr',
#        'Amtmann', 'Rektor', 'Provikar', 'Kanonikerin',
#        'Bischöflicher Rat', 'Vizearchidiakon', 'Confessar', 'Subdekan',
#        'Gewählter und bestätigter Bischof', 'Vizekämmerer',
#        'Nominierter Bischof', 'Ernannter Kardinal',
#        'Koadministrator in spiritualibus', 'Pfründenbewerber',
#        'Präbendar', 'Dekanatsbewerber',
#        'Generalvikar für das Obererzstift', 'Domschulmeister'],
#       dtype=object)

# %% [markdown]
# ### Create a csv file to be manually filled and later read to generate quickstatements

# %%
rows = []
for role in missing_roles:
    role_group_fq_id = missing_roles_df[missing_roles_df['name'] == role]['role_group_fq_id'].head(1).squeeze(axis=0)
    item_id = wiag_roles_df[wiag_roles_df['name'] == role].head(1).squeeze(axis=0)['id']
    if type(item_id) == pd.Series:
        item_id = ""
    row = {
        "Lde": f'{role}',
        "Len": "",
        "Lfr": "",
        "Dde": "",
        "Den": "",
        "P2": "Q37073",
        "P131": "Q153178",
        "item_id": item_id,
    }
    if not pd.isna(role_group_fq_id):
        row["P3"] = role_group_fq_id
    rows.append(row)
create_missing_roles_df = pd.DataFrame(rows)
create_missing_roles_df.to_csv(os.path.join(output_path, f"create-missing-roles-{today_string}.csv"))
create_missing_roles_df
# Out:
#                                    Lde Len Lfr Dde Den      P2     P131  \
# 0               Propst und Archidiakon                  Q37073  Q153178
# 1                          Domkämmerer                  Q37073  Q153178
# 2         Generalvikar des Erzbischofs                  Q37073  Q153178
# 3             Offizial des Erzbischofs                  Q37073  Q153178
# 4               Domthesaurar, Anwärter                  Q37073  Q153178
# ..                                 ...  ..  ..  ..  ..     ...      ...
# 123                   Pfründenbewerber                  Q37073  Q153178
# 124                          Präbendar                  Q37073  Q153178
# 125                   Dekanatsbewerber                  Q37073  Q153178
# 126  Generalvikar für das Obererzstift                  Q37073  Q153178
# 127                    Domschulmeister                  Q37073  Q153178
#
#     item_id       P3
# 0       202  Q648236
# 1       102  Q648232
# 2        44  Q648236
# 3        84  Q648236
# 4       143  Q648232
# ..      ...      ...
# 123              NaN
# 124              NaN
# 125              NaN
# 126      46  Q648236
# 127              NaN
#
# [128 rows x 9 columns]

# %%
filename = f"create-missing-roles-{today_string}.qs"
create_missing_roles_df = pd.read_csv('create-missing-roles-2024-05-28.csv', index_col=0)
ignore_cols = ['item_id']
string_cols = ['Lde', 'Len', 'Lfr', 'Dde', 'Den']
with open(filename, 'w') as file:
    for _, row in create_missing_roles_df.iterrows():
        file.write("CREATE\n")
        for col in create_missing_roles_df.columns:
            value = row[col]
            if pd.isna(value) and col in string_cols:
                value = ''
            if not pd.isna(value):
                if col in string_cols:
                    value = f'"{value}"'
                if col not in ignore_cols:
                    file.write("\t".join(["LAST", col, value + "\n"]))
print(filename)
# Out:
# create-missing-roles-2024-05-28.qs

# %%
filename = f"create-missing-roles-{today_string}.qs"
with open(filename, 'w') as file:
    for role in missing_roles:
        file.write("CREATE\n")
        file.write("\t".join(["LAST", "Lde", role + "\n"]))
        file.write("\t".join(["LAST", "P2", "Q37073\n"]))
        file.write("\t".join(["LAST", "P131", "Q153178\n"]))
        search_res = missing_roles_df[missing_roles_df['name'] == role]['role_group_fq_id'].head(1).squeeze(axis=0)
        if not pd.isna(search_res):
            file.write("\t".join(["LAST", "P3", search_res + "\n"]))
print(filename)

# %%
assert len(joined_df[joined_df['role_fg_id'].isna()]) == 0, "Missing roles with factgrid id in wiag database"

# %% [markdown]
# ## Check people with missing factgrid entries or missing factgrid ids in wiag

# %%
joined_df[joined_df['FactGrid'].isna()]
# Out:
#                       person_id      id          name  \
# 65    WIAG-Pers-CANON-80982-001   56198       Domherr
# 637   WIAG-Pers-CANON-25882-001  140432       Domherr
# 638   WIAG-Pers-CANON-25882-001  140434       Domherr
# 639   WIAG-Pers-CANON-25882-001  140436      Domdekan
# 640   WIAG-Pers-CANON-25882-001  140438  Generalvikar
# 1149  WIAG-Pers-CANON-48974-001  139834       Domherr
# 1228  WIAG-Pers-CANON-45781-001  139446       Domherr
# 1229  WIAG-Pers-CANON-45781-001  139448   Domcellerar
# 1230  WIAG-Pers-CANON-45781-001  139450     Domkustos
# 1231  WIAG-Pers-CANON-45781-001  139452       Domherr
# 1247  WIAG-Pers-CANON-48993-001  140558       Domherr
# 1248  WIAG-Pers-CANON-48993-001  140560       Domherr
# 1249  WIAG-Pers-CANON-48993-001  140562        Propst
# 1250  WIAG-Pers-CANON-48993-001  140564     Domkustos
# 1251  WIAG-Pers-CANON-48993-001  140566      Domdekan
# 1252  WIAG-Pers-CANON-48993-001  140568   Archidiakon
# 1327  WIAG-Pers-CANON-24731-001  140570       Domherr
# 1328  WIAG-Pers-CANON-24731-001  140572   Archidiakon
# 1329  WIAG-Pers-CANON-24731-001  140574     Kanoniker
# 1330  WIAG-Pers-CANON-24731-001  140576       Domherr
# 1331  WIAG-Pers-CANON-24731-001  140578       Domherr
# 1640  WIAG-Pers-CANON-25122-001  140838       Domherr
# 1641  WIAG-Pers-CANON-25122-001  140840       Domherr
# 1701  WIAG-Pers-CANON-49126-001  139950       Domherr
# 1702  WIAG-Pers-CANON-49126-001  139952     Domkustos
# 1703  WIAG-Pers-CANON-49126-001  139954     Domsenior
# 1915  WIAG-Pers-CANON-14941-001  139966       Domherr
# 1916  WIAG-Pers-CANON-14941-001  139968       Domherr
# 1917  WIAG-Pers-CANON-14941-001  139970   Domcellerar
# 1918  WIAG-Pers-CANON-14941-001  139972     Domsenior
# 1919  WIAG-Pers-CANON-14941-001  139974     Kanoniker
# 1999  WIAG-Pers-CANON-14944-001  139926       Domherr
# 2000  WIAG-Pers-CANON-14944-001  139928     Kanoniker
# 2001  WIAG-Pers-CANON-14944-001  139930     Kanoniker
# 2002  WIAG-Pers-CANON-14944-001  139932   Archidiakon
# 2003  WIAG-Pers-CANON-14944-001  139934   Archidiakon
# 2004  WIAG-Pers-CANON-14944-001  139936     Domkustos
# 2187  WIAG-Pers-CANON-15005-001  139922       Domherr
# 2188  WIAG-Pers-CANON-15005-001  139924       Domherr
# 2310  WIAG-Pers-CANON-26451-001  139416       Domherr
# 2311  WIAG-Pers-CANON-26451-001  139418    Domizellar
# 2312  WIAG-Pers-CANON-26451-001  139420       Domherr
# 2401  WIAG-Pers-CANON-15070-001  139978       Domherr
#
#                         role_group  \
# 65                    Amt Domstift
# 637                   Amt Domstift
# 638                   Amt Domstift
# 639           Leitungsamt Domstift
# 640            Leitungsamt Diözese
# 1149                  Amt Domstift
# 1228                  Amt Domstift
# 1229          Leitungsamt Domstift
# 1230          Leitungsamt Domstift
# 1231                  Amt Domstift
# 1247                  Amt Domstift
# 1248                  Amt Domstift
# 1249  Oberstes Leitungsamt Kloster
# 1250          Leitungsamt Domstift
# 1251          Leitungsamt Domstift
# 1252           Leitungsamt Diözese
# 1327                  Amt Domstift
# 1328           Leitungsamt Diözese
# 1329                     Amt Stift
# 1330                  Amt Domstift
# 1331                  Amt Domstift
# 1640                  Amt Domstift
# 1641                  Amt Domstift
# 1701                  Amt Domstift
# 1702          Leitungsamt Domstift
# 1703                  Amt Domstift
# 1915                  Amt Domstift
# 1916                  Amt Domstift
# 1917          Leitungsamt Domstift
# 1918                  Amt Domstift
# 1919                     Amt Stift
# 1999                  Amt Domstift
# 2000                     Amt Stift
# 2001                     Amt Stift
# 2002           Leitungsamt Diözese
# 2003           Leitungsamt Diözese
# 2004          Leitungsamt Domstift
# 2187                  Amt Domstift
# 2188                  Amt Domstift
# 2310                  Amt Domstift
# 2311                  Amt Domstift
# 2312                  Amt Domstift
# 2401                  Amt Domstift
#
#                                     role_group_en role_group_fq_id  \
# 65                  Cleric of a cathedral chapter          Q648226
# 637                 Cleric of a cathedral chapter          Q648226
# 638                 Cleric of a cathedral chapter          Q648226
# 639              Dignitary of a cathedral chapter          Q648232
# 640                      Head of an (arch)diocese          Q648236
# 1149                Cleric of a cathedral chapter          Q648226
# 1228                Cleric of a cathedral chapter          Q648226
# 1229             Dignitary of a cathedral chapter          Q648232
# 1230             Dignitary of a cathedral chapter          Q648232
# 1231                Cleric of a cathedral chapter          Q648226
# 1247                Cleric of a cathedral chapter          Q648226
# 1248                Cleric of a cathedral chapter          Q648226
# 1249  Monastery member with a leadership position          Q648233
# 1250             Dignitary of a cathedral chapter          Q648232
# 1251             Dignitary of a cathedral chapter          Q648232
# 1252                     Head of an (arch)diocese          Q648236
# 1327                Cleric of a cathedral chapter          Q648226
# 1328                     Head of an (arch)diocese          Q648236
# 1329  Affiliate of a collegiate church or convent          Q648228
# 1330                Cleric of a cathedral chapter          Q648226
# 1331                Cleric of a cathedral chapter          Q648226
# 1640                Cleric of a cathedral chapter          Q648226
# 1641                Cleric of a cathedral chapter          Q648226
# 1701                Cleric of a cathedral chapter          Q648226
# 1702             Dignitary of a cathedral chapter          Q648232
# 1703                Cleric of a cathedral chapter          Q648226
# 1915                Cleric of a cathedral chapter          Q648226
# 1916                Cleric of a cathedral chapter          Q648226
# 1917             Dignitary of a cathedral chapter          Q648232
# 1918                Cleric of a cathedral chapter          Q648226
# 1919  Affiliate of a collegiate church or convent          Q648228
# 1999                Cleric of a cathedral chapter          Q648226
# 2000  Affiliate of a collegiate church or convent          Q648228
# 2001  Affiliate of a collegiate church or convent          Q648228
# 2002                     Head of an (arch)diocese          Q648236
# 2003                     Head of an (arch)diocese          Q648236
# 2004             Dignitary of a cathedral chapter          Q648232
# 2187                Cleric of a cathedral chapter          Q648226
# 2188                Cleric of a cathedral chapter          Q648226
# 2310                Cleric of a cathedral chapter          Q648226
# 2311                Cleric of a cathedral chapter          Q648226
# 2312                Cleric of a cathedral chapter          Q648226
# 2401                Cleric of a cathedral chapter          Q648226
#
#                                             institution  institution_id  \
# 65                                     Domstift Bamberg          3492.0
# 637                                   Domstift Würzburg          3502.0
# 638                                    Domstift Bamberg          3492.0
# 639                                   Domstift Würzburg          3502.0
# 640                                                 NaN             NaN
# 1149                                   Domstift Bamberg          3492.0
# 1228                                   Domstift Bamberg          3492.0
# 1229                                   Domstift Bamberg          3492.0
# 1230                                   Domstift Bamberg          3492.0
# 1231                                  Domstift Augsburg          3498.0
# 1247                                   Domstift Bamberg          3492.0
# 1248                                  Domstift Würzburg          3502.0
# 1249  Benediktinerkloster Großcomburg (später Kolleg...         20154.0
# 1250                                  Domstift Würzburg          3502.0
# 1251                                  Domstift Würzburg          3502.0
# 1252                                                NaN             NaN
# 1327                                  Domstift Würzburg          3502.0
# 1328                                                NaN             NaN
# 1329  Benediktinerkloster Großcomburg (später Kolleg...         20154.0
# 1330                                  Domstift Würzburg          3502.0
# 1331                                   Domstift Bamberg          3492.0
# 1640                                  Domstift Würzburg          3502.0
# 1641                                   Domstift Bamberg          3492.0
# 1701                                   Domstift Bamberg          3492.0
# 1702                                   Domstift Bamberg          3492.0
# 1703                                   Domstift Bamberg          3492.0
# 1915                                   Domstift Bamberg          3492.0
# 1916                                 Domstift Eichstätt          3493.0
# 1917                                 Domstift Eichstätt          3493.0
# 1918                                   Domstift Bamberg          3492.0
# 1919  Benediktinerabtei/Kollegiatstift St. Burkard, ...          1070.0
# 1999                                   Domstift Bamberg          3492.0
# 2000  Benediktinerkloster Großcomburg (später Kolleg...         20154.0
# 2001  Benediktinerabtei/Kollegiatstift St. Burkard, ...          1070.0
# 2002                                                NaN             NaN
# 2003                                                NaN             NaN
# 2004                                   Domstift Bamberg          3492.0
# 2187                                   Domstift Bamberg          3492.0
# 2188                                  Domstift Würzburg          3502.0
# 2310                                   Domstift Bamberg          3492.0
# 2311                                  Domstift Würzburg          3502.0
# 2312                                     Domstift Worms          3490.0
# 2401                                   Domstift Bamberg          3492.0
#
#               diocese                  diocese_id  ...         GND  \
# 65     Bistum Bamberg  WIAG-Inst-DIOCGatz-002-001  ...         NaN
# 637               NaN                         NaN  ...   13948941X
# 638               NaN                         NaN  ...   13948941X
# 639               NaN                         NaN  ...   13948941X
# 640   Bistum Würzburg  WIAG-Inst-DIOCGatz-033-001  ...   13948941X
# 1149              NaN                         NaN  ...         NaN
# 1228              NaN                         NaN  ...         NaN
# 1229              NaN                         NaN  ...         NaN
# 1230              NaN                         NaN  ...         NaN
# 1231              NaN                         NaN  ...         NaN
# 1247              NaN                         NaN  ...  101217414X
# 1248              NaN                         NaN  ...  101217414X
# 1249              NaN                         NaN  ...  101217414X
# 1250              NaN                         NaN  ...  101217414X
# 1251              NaN                         NaN  ...  101217414X
# 1252  Bistum Würzburg  WIAG-Inst-DIOCGatz-033-001  ...  101217414X
# 1327              NaN                         NaN  ...         NaN
# 1328  Bistum Würzburg  WIAG-Inst-DIOCGatz-033-001  ...         NaN
# 1329              NaN                         NaN  ...         NaN
# 1330              NaN                         NaN  ...         NaN
# 1331              NaN                         NaN  ...         NaN
# 1640              NaN                         NaN  ...         NaN
# 1641              NaN                         NaN  ...         NaN
# 1701              NaN                         NaN  ...         NaN
# 1702              NaN                         NaN  ...         NaN
# 1703              NaN                         NaN  ...         NaN
# 1915              NaN                         NaN  ...  1107785820
# 1916              NaN                         NaN  ...  1107785820
# 1917              NaN                         NaN  ...  1107785820
# 1918              NaN                         NaN  ...  1107785820
# 1919              NaN                         NaN  ...  1107785820
# 1999              NaN                         NaN  ...         NaN
# 2000              NaN                         NaN  ...         NaN
# 2001              NaN                         NaN  ...         NaN
# 2002   Bistum Bamberg  WIAG-Inst-DIOCGatz-002-001  ...         NaN
# 2003   Bistum Bamberg  WIAG-Inst-DIOCGatz-002-001  ...         NaN
# 2004              NaN                         NaN  ...         NaN
# 2187              NaN                         NaN  ...         NaN
# 2188              NaN                         NaN  ...         NaN
# 2310              NaN                         NaN  ...         NaN
# 2311              NaN                         NaN  ...         NaN
# 2312              NaN                         NaN  ...         NaN
# 2401              NaN                         NaN  ...   140187669
#
#                 GSN  FactGrid fg_institution_id fg_gsn_id fg_diocese_id  \
# 65    007-01739-001       NaN           Q400530    3492.0       Q153216
# 637   012-01202-001       NaN           Q400557    3502.0          None
# 638   012-01202-001       NaN           Q400530    3492.0          None
# 639   012-01202-001       NaN           Q400557    3502.0          None
# 640   012-01202-001       NaN               NaN       NaN       Q153247
# 1149            NaN       NaN           Q400530    3492.0          None
# 1228            NaN       NaN           Q400530    3492.0          None
# 1229            NaN       NaN           Q400530    3492.0          None
# 1230            NaN       NaN           Q400530    3492.0          None
# 1231            NaN       NaN           Q898020    3498.0          None
# 1247  021-00051-001       NaN           Q400530    3492.0          None
# 1248  021-00051-001       NaN           Q400557    3502.0          None
# 1249  021-00051-001       NaN           Q898016   20154.0          None
# 1250  021-00051-001       NaN           Q400557    3502.0          None
# 1251  021-00051-001       NaN           Q400557    3502.0          None
# 1252  021-00051-001       NaN               NaN       NaN       Q153247
# 1327            NaN       NaN           Q400557    3502.0          None
# 1328            NaN       NaN               NaN       NaN       Q153247
# 1329            NaN       NaN           Q898016   20154.0          None
# 1330            NaN       NaN           Q400557    3502.0          None
# 1331            NaN       NaN           Q400530    3492.0          None
# 1640  052-00592-001       NaN           Q400557    3502.0          None
# 1641  052-00592-001       NaN           Q400530    3492.0          None
# 1701  052-02222-001       NaN           Q400530    3492.0          None
# 1702  052-02222-001       NaN           Q400530    3492.0          None
# 1703  052-02222-001       NaN           Q400530    3492.0          None
# 1915  054-02450-001       NaN           Q400530    3492.0          None
# 1916  054-02450-001       NaN           Q898024    3493.0          None
# 1917  054-02450-001       NaN           Q898024    3493.0          None
# 1918  054-02450-001       NaN           Q400530    3492.0          None
# 1919  054-02450-001       NaN           Q898014    1070.0          None
# 1999  054-02451-001       NaN           Q400530    3492.0          None
# 2000  054-02451-001       NaN           Q898016   20154.0          None
# 2001  054-02451-001       NaN           Q898014    1070.0          None
# 2002  054-02451-001       NaN               NaN       NaN       Q153216
# 2003  054-02451-001       NaN               NaN       NaN       Q153216
# 2004  054-02451-001       NaN           Q400530    3492.0          None
# 2187            NaN       NaN           Q400530    3492.0          None
# 2188            NaN       NaN           Q400557    3502.0          None
# 2310            NaN       NaN           Q400530    3492.0          None
# 2311            NaN       NaN           Q400557    3502.0          None
# 2312            NaN       NaN           Q898042    3490.0          None
# 2401            NaN       NaN           Q400530    3492.0          None
#
#            dioc_label          dioc_alt                dioc_wiag_id role_fg_id
# 65     Bistum Bamberg   Diözese Bamberg  WIAG-Inst-DIOCGatz-002-001     Q38837
# 637              None              None                        None     Q38837
# 638              None              None                        None     Q38837
# 639              None              None                        None     Q38836
# 640   Bistum Würzburg  Diözese Würzburg  WIAG-Inst-DIOCGatz-033-001     Q39117
# 1149             None              None                        None     Q38837
# 1228             None              None                        None     Q38837
# 1229             None              None                        None    Q893490
# 1230             None              None                        None    Q902176
# 1231             None              None                        None     Q38837
# 1247             None              None                        None     Q38837
# 1248             None              None                        None     Q38837
# 1249             None              None                        None    Q164776
# 1250             None              None                        None    Q902176
# 1251             None              None                        None     Q38836
# 1252  Bistum Würzburg  Diözese Würzburg  WIAG-Inst-DIOCGatz-033-001     Q38976
# 1327             None              None                        None     Q38837
# 1328  Bistum Würzburg  Diözese Würzburg  WIAG-Inst-DIOCGatz-033-001     Q38976
# 1329             None              None                        None     Q38823
# 1330             None              None                        None     Q38837
# 1331             None              None                        None     Q38837
# 1640             None              None                        None     Q38837
# 1641             None              None                        None     Q38837
# 1701             None              None                        None     Q38837
# 1702             None              None                        None    Q902176
# 1703             None              None                        None    Q902179
# 1915             None              None                        None     Q38837
# 1916             None              None                        None     Q38837
# 1917             None              None                        None    Q893490
# 1918             None              None                        None    Q902179
# 1919             None              None                        None     Q38823
# 1999             None              None                        None     Q38837
# 2000             None              None                        None     Q38823
# 2001             None              None                        None     Q38823
# 2002   Bistum Bamberg   Diözese Bamberg  WIAG-Inst-DIOCGatz-002-001     Q38976
# 2003   Bistum Bamberg   Diözese Bamberg  WIAG-Inst-DIOCGatz-002-001     Q38976
# 2004             None              None                        None    Q902176
# 2187             None              None                        None     Q38837
# 2188             None              None                        None     Q38837
# 2310             None              None                        None     Q38837
# 2311             None              None                        None     Q38838
# 2312             None              None                        None     Q38837
# 2401             None              None                        None     Q38837
#
# [43 rows x 23 columns]

# %%
joined_df[joined_df['FactGrid'].isna()]['person_id'].unique()
# Out:
# array(['WIAG-Pers-CANON-80982-001', 'WIAG-Pers-CANON-25882-001',
#        'WIAG-Pers-CANON-48974-001', 'WIAG-Pers-CANON-45781-001',
#        'WIAG-Pers-CANON-48993-001', 'WIAG-Pers-CANON-24731-001',
#        'WIAG-Pers-CANON-25122-001', 'WIAG-Pers-CANON-49126-001',
#        'WIAG-Pers-CANON-14941-001', 'WIAG-Pers-CANON-14944-001',
#        'WIAG-Pers-CANON-15005-001', 'WIAG-Pers-CANON-26451-001',
#        'WIAG-Pers-CANON-15070-001'], dtype=object)

# %% [markdown]
# ## (Optinally) generate the quickstatements for creating the persons here

# %%
joined_df[joined_df['FactGrid'].isna()].to_csv(os.path.join(output_path, f'missing_factgrid-{today_string}_Bamberg.csv', sep=';'))

# %% [markdown]
# ## The cell below will throw an error if there are entries on Factgrid but not on Wiag

# %%
assert joined_df[joined_df['FactGrid'].isna()].empty, "There are missing persons on factgrid"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 assert joined_df[joined_df['FactGrid'].isna()].empty, "There are missing persons on factgrid"
#
# AssertionError: There are missing persons on factgrid

# %% [markdown]
# ## WARNING: the code section below ignores all entries absent on factgrid

# %%
joined_df = joined_df[~joined_df['FactGrid'].isna()]

# %%
factgrid_inst_roles_df
# Out:
#      fg_inst_role_id                                          inst_role
# 0            Q172316                    Generalvikar der Diözese Trento
# 1            Q172317                   Generalvikar der Diözese Utrecht
# 2            Q172318                    Generalvikar der Diözese Vienna
# 3            Q172319                  Generalvikar der Diözese Lausanne
# 4            Q172320                Generalvikar der Diözese Pomesanien
# ...              ...                                                ...
# 4338         Q452118   Schauspieler/Schauspielerin des Künstlertheaters
# 4339         Q452119             Schauspieler/in des Belvárosi-Theaters
# 4340         Q452120    Schauspieler/Schauspielerin des Pester Theaters
# 4341         Q452121  Schauspieler/Schauspielerin des Theaters der U...
# 4342         Q452122     Direktor des Jókai-Theaters des Komitats Békés
#
# [4343 rows x 2 columns]

# %% [markdown]
# ## Add factgrid ids for roles
# Note: this role has information of the institution as well

# %%
# add factgrid ids for roles
found = 0
data_dict = {}
not_found = []
dupl = {}
for i, (name, inst, dioc) in joined_df[['name', 'institution', 'diocese']].iterrows():
    if name == "Kardinal":
        # this is okay
        # manually add qid for kardinals Q254893
        data_dict[i] = "Q254893"
        continue
    search_res = pd.DataFrame()
    if pd.isna(inst):
    # if name in ["Bischof", "Fürstbischof", "Ernannter Bischof", "Erzbischof"]:
        if pd.isna(dioc):
            print(i, name, inst, dioc)
        if name not in ["Archidiakon", "Koadjutor"]:
            dioc = dioc.lstrip('Bistum').lstrip('Erzbistum').lstrip('Patriarchat').lstrip()
        if name == "Fürstbischof" and dioc in ["Passau", "Straßburg"]:
            name = "Bischof"    
        search_res = factgrid_inst_roles_df[factgrid_inst_roles_df['inst_role'].str.contains(f"^{name}.*{dioc}")]
        if name == "Erzbischof" and dioc == "Salzburg":
            # will be merged in later
            search_res = factgrid_inst_roles_df[factgrid_inst_roles_df['fg_inst_role_id'] == 'Q172567']
    else:
        name = name.replace('Domkanoniker', 'Domherr')
        search_res = factgrid_inst_roles_df[factgrid_inst_roles_df['inst_role'] == f"{name} {inst}"]
    if len(search_res) == 1:
        found += 1
        data_dict[i] = search_res['fg_inst_role_id'].values[0]
    elif len(search_res) >= 2:
        # print("+" * 10)
        print(name, inst, dioc)
        print(search_res)
        print()
        dupl[i] = (name, inst, dioc, search_res)
    elif len(search_res) == 0:
        not_found.append((name, inst, dioc))
        print(name, inst, dioc)
print("===Summary of roles===")
print("Found:", found, "Duplicates:", len(dupl), "Not found:", len(not_found))
# Out:
# Propst Kollegiatstift St. Nikolaus, Spalt nan
# Domsenior Domstift Würzburg nan
# Cellerar Domstift Eichstätt nan
# Propst Benediktinerkloster, später Kollegiatstift St. Cyriakus, Wiesensteig nan
# Domscholaster Domstift Eichstätt nan
# Domcellerar Domstift Augsburg nan
# Kapitularvikar nan Würzburg
# Propst Kollegiatstift Unsere Liebe Frau, Eichstätt nan
# ===Summary of roles===
# Found: 2742 Duplicates: 0 Not found: 8

# %%
final_joined_df = joined_df.merge(pd.Series(data_dict).rename('fg_inst_role_id'), left_index=True, right_index=True)
print(len(final_joined_df))
final_joined_df.head()
# Out:
# 2743
#                        person_id     id        name  \
# 0  WIAG-Pers-EPISCGatz-05072-001   5154  Erzbischof
# 1  WIAG-Pers-EPISCGatz-04050-001   3770     Bischof
# 2      WIAG-Pers-CANON-24965-001  22325     Domherr
# 3      WIAG-Pers-CANON-24965-001  31418     Domherr
# 4  WIAG-Pers-EPISCGatz-03869-001   3586     Bischof
#
#                      role_group                  role_group_en  \
# 0  Oberstes Leitungsamt Diözese       Head of an (arch)diocese
# 1  Oberstes Leitungsamt Diözese       Head of an (arch)diocese
# 2                  Amt Domstift  Cleric of a cathedral chapter
# 3                  Amt Domstift  Cleric of a cathedral chapter
# 4  Oberstes Leitungsamt Diözese       Head of an (arch)diocese
#
#   role_group_fq_id        institution  institution_id           diocese  \
# 0          Q648236                NaN             NaN   Erzbistum Trier
# 1          Q648236                NaN             NaN  Bistum Eichstätt
# 2          Q648226  Domstift Würzburg          3502.0               NaN
# 3          Q648226   Domstift Bamberg          3492.0               NaN
# 4          Q648236                NaN             NaN    Bistum Bamberg
#
#                    diocese_id  ...            GSN FactGrid  fg_institution_id  \
# 0  WIAG-Inst-DIOCGatz-030-001  ...  062-01186-001  Q653844                NaN
# 1  WIAG-Inst-DIOCGatz-006-001  ...  059-00710-001  Q652691                NaN
# 2                         NaN  ...            NaN  Q728753            Q400557
# 3                         NaN  ...            NaN  Q728753            Q400530
# 4  WIAG-Inst-DIOCGatz-002-001  ...  006-00007-001  Q652702                NaN
#
#   fg_gsn_id fg_diocese_id        dioc_label           dioc_alt  \
# 0       NaN       Q153244   Erzbistum Trier       Bistum Trier
# 1       NaN       Q153220  Bistum Eichstätt  Diözese Eichstätt
# 2    3502.0          None              None               None
# 3    3492.0          None              None               None
# 4       NaN       Q153216    Bistum Bamberg    Diözese Bamberg
#
#                  dioc_wiag_id role_fg_id fg_inst_role_id
# 0  WIAG-Inst-DIOCGatz-030-001    Q172539         Q172572
# 1  WIAG-Inst-DIOCGatz-006-001     Q38809         Q172630
# 2                        None     Q38837         Q390632
# 3                        None     Q38837         Q400601
# 4  WIAG-Inst-DIOCGatz-002-001     Q38809         Q195266
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Parse begin and end date from the wiag data

# %%
# https://database.factgrid.de/query/embed.html#SELECT%20%3FPropertyLabel%20%3FProperty%20%3FPropertyDescription%20%3Freciprocal%20%3FreciprocalLabel%20%3Fexample%20%3Fuseful_statements%20%3Fwd%20WHERE%20%7B%0A%20%20SERVICE%20wikibase%3Alabel%20%7B%20bd%3AserviceParam%20wikibase%3Alanguage%20%22en%22.%20%7D%0A%20%20%3FProperty%20wdt%3AP8%20wd%3AQ77483.%0A%20%20OPTIONAL%20%7B%20%3FProperty%20wdt%3AP364%20%3Fexample.%20%7D%0A%20%20OPTIONAL%20%7B%20%3FProperty%20wdt%3AP86%20%3Freciprocal.%20%7D%0A%20%20OPTIONAL%20%7B%20%3FProperty%20wdt%3AP343%20%3Fwd.%20%7D%0A%20%20OPTIONAL%20%7B%20%3FProperty%20wdt%3AP310%20%3Fuseful_statements.%20%7D%0A%7D%0AORDER%20BY%20%3FPropertyLabel

def format_datetime(entry: datetime, resolution):
    julian_ending = "/J" if entry.year < 1582 else ""
    ret_val =  f"+{entry.isoformat()}Z/{resolution}" + julian_ending
    if resolution <= 9:
        ret_val = ret_val.replace(f"{entry.year}-01-01", f"{entry.year}-00-00", 1)
    return ret_val

def date_parsing(date_string: str, end=False, only_date=False):
    return_property = "P106" if only_date else "P50" if end else "P49"
    qualifier = None
    entry = None
    resolution = 7
    string_precision_qualifier_clause = ("P73" if only_date else "P788" if end else "P787") + f'\t"{date_string}"'
    exact_precision_qualifier = ("P73" if only_date else "P786" if end else "P785")

    if pd.isna(date_string) or date_string == '?':
        return tuple()
    
    if matches := re.match(r'frühestens (\d{3,4})', date_string):
        return_property = "P41" if only_date else "P1125" if end else "P1126"
        entry = datetime(int(matches.group(1)), 1, 1)
        resolution = 9
    
    elif matches := re.match(r'(kurz )?vor (\d{3,4})', date_string):
        return_property = "P43" if only_date else "P1123" if end else "P1124"
        if matches.group(1):
            qualifier = string_precision_qualifier_clause
        entry = datetime(int(matches.group(2)), 1, 1)
        resolution = 9
        
    elif matches := re.match(r'(kurz )?nach (\d{3,4})', date_string):
        return_property = "P41" if only_date else "P1125" if end else "P1126"
        if matches.group(1):
            qualifier = string_precision_qualifier_clause
        entry = datetime(int(matches.group(2)), 1, 1)
        resolution = 9
        
    elif matches := re.match(r'(\d{1,2})\. Jahrhundert', date_string):
        century = int(matches.group(1))
        entry = datetime(100 * (century), 1, 1)
    
    elif matches := re.match(r'(\d)\. Hälfte (des )?(\d{1,2})\. (Jhs\.|Jahrhunderts|Jahrhundert)', date_string):
        half = int(matches.group(1))
        year = int(matches.group(3)) - 1
        latest_year   = year * 100 + (half * 50)
        earliest_year = latest_year - 50 + 1
        entry = datetime((earliest_year + latest_year) // 2, 1, 1)
        qualifier = string_precision_qualifier_clause
    
    elif matches := re.match(r'(\w+) Viertel des (\d{1,2})\. Jhs\.', date_string):
        number_map = {
            "erstes":  1,
            "zweites": 2,
            "drittes": 3,
            "viertes": 4,
        }
        quarter = number_map[matches.group(1)]
        year    = int(matches.group(2)) - 1
        latest_year   = year * 100 + (quarter * 25)
        earliest_year = latest_year - 25 + 1
        entry = datetime((earliest_year + latest_year) // 2, 1, 1)
        qualifier = string_precision_qualifier_clause

    elif matches := re.match(r'frühes (\d{1,2})\. Jh\.', date_string):
        year = int(matches.group(1)) - 1
        latest_year   = year * 100 + 20
        earliest_year = latest_year - 20 + 1
        entry = datetime((earliest_year + latest_year) // 2, 1, 1)
        qualifier = string_precision_qualifier_clause

    elif matches := re.match(r'spätes (\d{1,2})\. Jh\.', date_string):
        year = int(matches.group(1))
        latest_year   = year * 100
        earliest_year = latest_year - 20 + 1
        entry = datetime((earliest_year + latest_year) // 2, 1, 1)
        qualifier = string_precision_qualifier_clause

    elif matches := re.match(r'(Anfang|Mitte|Ende) (\d{1,2})\. Jh\.', date_string):
        number_map = {
            "Anfang":  1,
            "Mitte": 2,
            "Ende": 3,
        }
        third = number_map[matches.group(1)]
        year = int(matches.group(2)) - 1
        latest_year   = year * 100 + (third * 33)
        earliest_year = latest_year - 33 + 1
        entry = datetime((earliest_year + latest_year) // 2, 1, 1)
        qualifier = string_precision_qualifier_clause

    elif matches := re.match(r'(ca\.|um) (\d{3,4})', date_string):
        year = int(matches.group(2))
        latest_year   = year + 5
        earliest_year = latest_year - 10
        entry = datetime((earliest_year + latest_year) // 2, 1, 1)
        resolution = 9
        qualifier = exact_precision_qualifier + "\tQ10"

    elif matches := re.match(r'(\d{3,4})er Jahre', date_string):
        year = int(matches.group(1))
        latest_year   = year + 10
        earliest_year = latest_year - 10 + 1
        entry = datetime(year, 1, 1)
        resolution = 8
    
    elif matches := re.match(r'Wende zum (\d{1,2})\. Jh\.', date_string):
        year = int(matches.group(1)) - 1
        latest_year   = year * 100 + 10
        earliest_year = latest_year - 20 + 1
        entry = datetime(latest_year, 1, 1)
        qualifier = string_precision_qualifier_clause

    elif matches := re.match(r'Anfang der (\d{3,4})er Jahre', date_string):
        year = int(matches.group(1))
        latest_year   = year + 3
        earliest_year = year
        entry = datetime(year, 1, 1)
        resolution = 8
        qualifier = string_precision_qualifier_clause

    elif matches := re.match(r'\((\d{3,4}) \?\) (\d{3,4})', date_string):
        year1 = int(matches.group(1))
        year2 = int(matches.group(2))
        entry = datetime(year2, 1, 1)
        resolution = 9
        qualifier = string_precision_qualifier_clause
    
    elif matches := re.match(r'(\d{3,4})/(\d{3,4})', date_string):
        year1 = int(matches.group(1))
        year2 = int(matches.group(2))

        if year2 - year1 == 1:
            # check for consecutive years
            qualifier = exact_precision_qualifier + "\tQ912616"
        entry = datetime(year1, 1, 1)
        resolution = 9

    elif matches := re.match(r'(\d{3,4})\?', date_string):
        year = int(matches.group(1))
        entry = datetime(year, 1, 1)
        resolution = 9
        qualifier = exact_precision_qualifier + f'\t"{date_string}"'
    
    elif matches := re.match(r'(\d{3,4})', date_string):
        year = int(matches.group(1))
        entry = datetime(year, 1, 1)
        resolution = 9
    else:
        print(date_string)
        raise Exception("Couldn't parse date")
        
    if qualifier:
        return (return_property, format_datetime(entry, resolution), qualifier)
    else:
        return (return_property, format_datetime(entry, resolution))

tests = {
    "1205": "+1205-00-00T00:00:00Z/9/J",
    "12. Jahrhundert": "+1200-00-00T00:00:00Z/7/J",
    "1. Hälfte des 12. Jhs.": "+1125-00-00T00:00:00Z/7/J",
    "2. Hälfte des 12. Jhs.": "+1175-00-00T00:00:00Z/7/J",
    "erstes Viertel des 12. Jhs.": "+1113-00-00T00:00:00Z/7/J",
    "zweites Viertel des 12. Jhs.": "+1138-00-00T00:00:00Z/7/J",
    "drittes Viertel des 12. Jhs.": "+1163-00-00T00:00:00Z/7/J",
    "viertes Viertel des 12. Jhs.": "+1188-00-00T00:00:00Z/7/J",
    "frühes 12. Jh.": "+1110-00-00T00:00:00Z/7/J",
    "spätes 12. Jh.": "+1190-00-00T00:00:00Z/7/J",
    "Anfang 12. Jh.": "+1117-00-00T00:00:00Z/7/J",
    "Mitte 12. Jh.": "+1150-00-00T00:00:00Z/7/J",
    "Ende 12. Jh.": "+1183-00-00T00:00:00Z/7/J",
    "ca. 1050": "+1050-00-00T00:00:00Z/9/J",
    "um 1050": "+1050-00-00T00:00:00Z/9/J",
    "1230er Jahre": "+1230-00-00T00:00:00Z/8/J",
    "Wende zum 12. Jh.": "+1110-00-00T00:00:00Z/7/J",
    "Anfang der 1480er Jahre": "+1480-00-00T00:00:00Z/8/J",
    "frühestens 1342": "+1342-00-00T00:00:00Z/9/J",
    "vor 1230": "+1230-00-00T00:00:00Z/9/J",
    "nach 1230": "+1230-00-00T00:00:00Z/9/J",
    "kurz vor 1200": "+1200-00-00T00:00:00Z/9/J",
    "kurz nach 1200": "+1200-00-00T00:00:00Z/9/J",
    "1164/1165": "+1164-00-00T00:00:00Z/9/J",
    "1164/1177": "+1164-00-00T00:00:00Z/9/J",
}

for key, value in tests.items():
    retval = date_parsing(key)[1]
    assert retval == value, f"{key}: Returned {retval} instead of {value}"

# %% [markdown]
# ## Reconcile office data with factgrid

# %%
#https://database.factgrid.de/wiki/Special:EntityData/Q515.json

# %% [markdown]
# ## Generate quickstatements for offices

# %%
with open(f'quickstatments_{today_string}.qs', 'w') as file:
    for _, row in final_joined_df.iterrows():
        try:
            date_clauses = ()
            if pd.isna(row['date_begin']):
                date_clauses = date_parsing(row['date_begin'], only_date=True)
            elif pd.isna(row['date_end']):
                date_clauses = date_parsing(row['date_begin'], only_date=True)
            else:
                date_clauses = (*date_parsing(row['date_begin']), *date_parsing(row['date_end'], end=True))
            file.write('\t'.join([
                row['FactGrid'], 
                'P165', 
                row['fg_inst_role_id'],
                'S601', 
                '"' + row['person_id'] + '"',
                *date_clauses,
            ]) + '\n')
        except Exception as e:
            print(traceback.format_exc())
            print(row)

# %%
final_joined_df[final_joined_df['name'] == 'Kanoniker'][final_joined_df['person_id'] == 'WIAG-Pers-EPISCGatz-10347-001']
# Out:
# C:\Users\khan32\AppData\Local\Temp\ipykernel_7824\3387915465.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   final_joined_df[final_joined_df['name'] == 'Kanoniker'][final_joined_df['person_id'] == 'WIAG-Pers-EPISCGatz-10347-001']
#                           person_id      id       name role_group  \
# 2434  WIAG-Pers-EPISCGatz-10347-001  137596  Kanoniker  Amt Stift
# 2436  WIAG-Pers-EPISCGatz-10347-001  137600  Kanoniker  Amt Stift
# 2439  WIAG-Pers-EPISCGatz-10347-001  137606  Kanoniker  Amt Stift
#
#                                     role_group_en role_group_fq_id  \
# 2434  Affiliate of a collegiate church or convent          Q648228
# 2436  Affiliate of a collegiate church or convent          Q648228
# 2439  Affiliate of a collegiate church or convent          Q648228
#
#                                             institution  institution_id  \
# 2434                   Kollegiatstift St. Viktor, Mainz          3249.0
# 2436  Kollegiatstift St. Peter und St. Alexander, As...          1016.0
# 2439  Benediktinerabtei, dann Kollegiatstift St. Alb...          3241.0
#
#      diocese diocese_id  ...            GSN FactGrid  fg_institution_id  \
# 2434     NaN        NaN  ...  082-01197-001  Q654987            Q400416
# 2436     NaN        NaN  ...  082-01197-001  Q654987            Q400401
# 2439     NaN        NaN  ...  082-01197-001  Q654987            Q400526
#
#      fg_gsn_id fg_diocese_id dioc_label dioc_alt  dioc_wiag_id role_fg_id  \
# 2434    3249.0          None       None     None          None     Q38823
# 2436    1016.0          None       None     None          None     Q38823
# 2439    3241.0          None       None     None          None     Q38823
#
#      fg_inst_role_id
# 2434         Q907996
# 2436         Q400574
# 2439         Q907994
#
# [3 rows x 24 columns]

# %%
# all_roles = set()

# def add_possible_list(a_set: set, element):
#     if type(element) == list:
#         # add all items in list
#         for item in element:
#             a_set.add(item)
#     else:
#         # simply add the given element
#         a_set.add(element)

# for summary in missing_on_factgrid_df['summary_offices'].tolist():
#     print(summary)
#     offices = re.split(r'(\d+),', summary)
#     offices = [office.lstrip() for office in offices]
#     new_offices = offices
#     for index, office in enumerate(offices):
#         if re.match('\d+', office):
#             new_offices[index - 1] += office
#             new_offices.pop(index)
#     print(new_offices)
#     for office in new_offices:
#         for office_name in re.match(r'\w+(, \w+)*', office).group().split(','):
#             office_name = office_name.strip()
#             print(office_name)
#             all_roles.add(office_name)
#     print()

# print('#'*10)
# print(all_roles)

# url = 'https://database.factgrid.de/sparql'
# query = (
#     f"""SELECT DISTINCT ?item ?label
# WHERE
# {{
#   ?item wdt:P2 wd:Q37073;
#         rdfs:label ?label.
#   FILTER(LANG(?label) = "de").
#   FILTER REGEX (?label, "({'|'.join(list(all_roles))})$").
# }}
# ORDER BY ?label  
# """
# )
# print(query)
# # SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }

# # make request: 
# r = requests.get(url, params={'query': query}, headers={"Accept": "application/json"})
# data = r.json()
# factgrid_roles_df = pd.json_normalize(data['results']['bindings'])

# len(factgrid_roles_df)

# list(all_roles)
