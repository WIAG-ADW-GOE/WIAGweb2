# %% [markdown]
# # Update wiag id (in table persons) in Digitales Personenregister
#
# Updates PR with the WIAG IDs assigned to each person, ensuring PR remains the primary and up-to-date source of data.
#
# ## Requirements:
# * You need access to the following sql databases at https://vwebfile.gwdg.de/phpmyadmin/:
#   * wiag database
#   * personen register database

# %%
import requests
import csv
import os
import pandas as pd
import json
import re
import os
from datetime import datetime
today_string = datetime.now().strftime('%Y-%m-%d')

# %% [markdown]
# Change the path below to where you store your csv files. These directories can be anywhere but it's recommended that you use the `input_files` and `output_files` directories inside the `notebooks/sync_notebooks` directory inside the code directory.

# %%
input_path = r"C:\Users\khan32\Documents\WIAGweb2\notebooks\input_files"
output_path = r"C:\Users\khan32\Documents\WIAGweb2\notebooks\output_files"

# %% [markdown]
# # Get data from wiag
#
# Run the following sql query on the wiag database (https://vwebfile.gwdg.de/phpmyadmin/) and then export the results as csv. Please refer to the instructions at [Run_SQL_Query_and_Export_CSV.md](https://github.com/WIAG-ADW-GOE/WIAGweb2/blob/main/notebooks/sync_notebooks/docs/Run_SQL_Query_and_Export_CSV.md) for a detailed explanation of running the sql command below.
#
#
# ```sql
# SELECT DISTINCT
#   i.id,
#   CASE
#     WHEN t_id.epc IS NOT NULL THEN t_id.epc
#     WHEN t_id.epc IS NULL AND t_id.can IS NOT NULL THEN t_id.can
#     WHEN t_id.epc IS NULL AND t_id.can IS NULL AND t_id.dreg_can IS NOT NULL THEN t_id.dreg_can
#   END AS id_public,
#   uext.value AS gsn
# FROM
#   item AS i
# JOIN
#   url_external AS uext ON uext.item_id = i.id AND uext.authority_id = 200
# JOIN
#   item_name_role AS inr ON inr.item_id_name = i.id
# JOIN
#   (SELECT DISTINCT
#       ic.item_id AS item_id,
#       ic_ii.id_public AS epc,
#       ic_iii.id_public AS can,
#       ic_iv.id_public AS dreg_can
#    FROM
#       item_corpus AS ic
#    LEFT JOIN
#       item_corpus AS ic_ii ON ic_ii.item_id = ic.item_id AND ic_ii.corpus_id = 'epc'
#    LEFT JOIN
#       item_corpus AS ic_iii ON ic_iii.item_id = ic.item_id AND ic_iii.corpus_id = 'can'
#    LEFT JOIN
#       item_corpus AS ic_iv ON ic_iv.item_id = ic.item_id AND ic_iv.corpus_id = 'dreg-can'
#    WHERE
#       ic.corpus_id IN ('epc', 'can', 'dreg-can')
#   ) AS t_id ON t_id.item_id = i.id
# WHERE
#   i.is_online = 1;
# ```

# %% [markdown]
# Please change the filename below so that it matches the file that you just downloaded above. Then please move it to the `input_path` directory defined above.
#
# It's recommended that you change the filename to include the recent date. The code cell below show's an example of such a file name.

# %%
filename = 'item_2024_12_02.csv'

# %%
orig_ic_df = pd.read_csv(os.path.join(input_path, filename), names=["id", "wiag_id", "pd_id"])
ic_df = orig_ic_df
ic_df
# Out:
#           id                        wiag_id          pd_id
# 0      13008  WIAG-Pers-EPISCGatz-21120-001  006-00056-001
# 1      13009  WIAG-Pers-EPISCGatz-21119-001  070-01102-001
# 2      13038  WIAG-Pers-EPISCGatz-21018-001  084-00204-001
# 3      13051  WIAG-Pers-EPISCGatz-21004-001  006-00074-001
# 4      13052  WIAG-Pers-EPISCGatz-21002-001  006-00070-001
# ...      ...                            ...            ...
# 11043  16588  WIAG-Pers-EPISCGatz-10098-001  076-00804-001
# 11044  17054  WIAG-Pers-EPISCGatz-10715-001  082-00940-001
# 11045  59821  WIAG-Pers-EPISCGatz-10667-001  068-01800-001
# 11046  14888  WIAG-Pers-EPISCGatz-03418-001  059-00072-001
# 11047  59767      WIAG-Pers-CANON-26094-001  068-01325-001
#
# [11048 rows x 3 columns]

# %% [markdown]
# ## Check data from wiag and remove identical records

# %% [markdown]
# ### The following code block should be empty

# %%
ic_df[ic_df['pd_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, wiag_id, pd_id]
# Index: []

# %% [markdown]
# # Get data from Personenregister
#
# Run the following sql query on the Personenregister database and then export the results as csv. The exported csv needs to be in the same directory.
#
# ```sql
# SELECT persons.wiag, persons.id, gsn.id, gsn.nummer
# FROM items
# INNER JOIN persons ON persons.item_id = items.id AND persons.deleted=0 AND items.deleted=0 AND items.status = "online"
# INNER JOIN gsn ON gsn.item_id = items.id AND gsn.deleted=0
# WHERE persons.wiag IS NOT NULL AND persons.wiag != ''
# group by persons.wiag
# having gsn.id=min(gsn.id)
# ```
#
# <!--
# old version
# ```sql
# SELECT persons.wiag, MIN(gsn.nummer)
# FROM items
# INNER JOIN persons ON persons.item_id = items.id AND persons.deleted=0 AND items.deleted=0 AND items.status = "online"
# INNER JOIN gsn ON gsn.item_id = items.id AND gsn.deleted=0
# WHERE persons.wiag IS NOT NULL AND persons.wiag != ''
# GROUP BY persons.wiag
# ``` -->

# %% [markdown]
# ### (Ignore) Another useful query
#
# ```sql
# select DISTINCT persons.wiag, gsn.id, gsn.nummer
# from persons
# inner join gsn ON gsn.item_id = persons.item_id
# where persons.wiag in (
#     SELECT persons.wiag
#     FROM items
#     INNER JOIN persons ON persons.item_id = items.id AND persons.deleted=0 AND items.deleted=0 AND items.status = "online"
#     INNER JOIN gsn ON gsn.item_id = items.id AND gsn.deleted=0
#     WHERE persons.wiag IS NOT NULL AND persons.wiag != ''
#     GROUP BY persons.wiag
#     having count(*) > 1
# )
# order by persons.wiag
# ```

# %% [markdown]
# Please change the file name below to match the file that you recently downloaded.

# %%
filename = 'pr_2024-12-02.csv'

# %%
pr_df = pd.read_csv(os.path.join(input_path, filename), names=["wiag_id", "id", "gsn_table_id", "pd_id"])
pr_df
# Out:
#                              wiag_id      id  gsn_table_id          pd_id
# 0                            Q112009  337342        396166  086-00454-001
# 1                          Q55122442  339060        402484  055-01193-001
# 2          WIAG-Pers-CANON-10014-001  226042        192200  054-02832-001
# 3          WIAG-Pers-CANON-10032-001  339026        402386  032-02373-001
# 4          WIAG-Pers-CANON-10047-001  339024        402382  029-03106-001
# ...                              ...     ...           ...            ...
# 10997  WIAG-Pers-EPISCGatz-21735-001  252575        261488  061-06324-001
# 10998  WIAG-Pers-EPISCGatz-21750-001  219379        189218  052-02662-001
# 10999  WIAG-Pers-EPISCGatz-21751-001  303871        328143  077-00515-001
# 11000  WIAG-Pers-EPISCGatz-21766-001  297929        314418  073-01566-001
# 11001  WIAG-Pers-EPISCGatz-21773-001  303773        327925  077-00297-001
#
# [11002 rows x 4 columns]

# %% [markdown]
# ## Check if there are any problems with the data

# %% [markdown]
# If this is empty, there are no problems.

# %%
pr_df[pr_df['pd_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [wiag_id, id, gsn_table_id, pd_id]
# Index: []

# %%
pr_df_gp = pr_df.groupby('wiag_id').count()
pr_df_gp[pr_df_gp['pd_id'] > 1]
# Out:
# Empty DataFrame
# Columns: [id, gsn_table_id, pd_id]
# Index: []

# %% [markdown]
# # Compare records

# %%
joined_df = ic_df.merge(pr_df, on='pd_id', suffixes=('_wiag', '_pd'))
joined_df
# Out:
#        id_wiag                   wiag_id_wiag          pd_id  \
# 0        13008  WIAG-Pers-EPISCGatz-21120-001  006-00056-001
# 1        13009  WIAG-Pers-EPISCGatz-21119-001  070-01102-001
# 2        13038  WIAG-Pers-EPISCGatz-21018-001  084-00204-001
# 3        13051  WIAG-Pers-EPISCGatz-21004-001  006-00074-001
# 4        13052  WIAG-Pers-EPISCGatz-21002-001  006-00070-001
# ...        ...                            ...            ...
# 10990    16588  WIAG-Pers-EPISCGatz-10098-001  076-00804-001
# 10991    17054  WIAG-Pers-EPISCGatz-10715-001  082-00940-001
# 10992    59821  WIAG-Pers-EPISCGatz-10667-001  068-01800-001
# 10993    14888  WIAG-Pers-EPISCGatz-03418-001  059-00072-001
# 10994    59767      WIAG-Pers-CANON-26094-001  068-01325-001
#
#                           wiag_id_pd   id_pd  gsn_table_id
# 0      WIAG-Pers-EPISCGatz-21120-001  334162        390898
# 1      WIAG-Pers-EPISCGatz-21119-001  321113        363804
# 2      WIAG-Pers-EPISCGatz-21018-001  331642        382803
# 3      WIAG-Pers-EPISCGatz-21004-001  300667        323238
# 4      WIAG-Pers-EPISCGatz-21002-001  307523        338553
# ...                              ...     ...           ...
# 10990  WIAG-Pers-EPISCGatz-10098-001  324766        371909
# 10991  WIAG-Pers-EPISCGatz-10715-001  325009        370938
# 10992  WIAG-Pers-EPISCGatz-10667-001  338808        401286
# 10993  WIAG-Pers-EPISCGatz-03418-001  335581        394153
# 10994      WIAG-Pers-CANON-26094-001  274336        152975
#
# [10995 rows x 6 columns]

# %%
unequal_df = joined_df[joined_df['wiag_id_wiag'] != joined_df['wiag_id_pd']]
print(len(unequal_df))
unequal_df
# Out:
# 39
#        id_wiag                   wiag_id_wiag          pd_id  \
# 10564    62200      WIAG-Pers-CANON-53445-001  052-02090-001
# 10585    40165      WIAG-Pers-CANON-25701-001  021-00603-001
# 10631    59903      WIAG-Pers-CANON-45751-001  007-02183-001
# 10637    60774      WIAG-Pers-CANON-51356-001  054-01166-001
# 10639    62342      WIAG-Pers-CANON-49407-001  084-00687-001
# 10652    40215      WIAG-Pers-CANON-25779-001  054-01582-001
# 10666    62370      WIAG-Pers-CANON-53414-001  002-02448-001
# 10688    49117      WIAG-Pers-CANON-45036-001  068-01830-001
# 10698    36718      WIAG-Pers-CANON-17971-001  076-01492-001
# 10704    62464      WIAG-Pers-CANON-53546-001  052-02292-001
# 10714    52785      WIAG-Pers-CANON-49233-001  005-01681-001
# 10718    52700      WIAG-Pers-CANON-49138-001  023-01600-001
# 10722    52952      WIAG-Pers-CANON-49426-001  036-04549-001
# 10732    61302      WIAG-Pers-CANON-52044-001  054-01950-001
# 10735    56695      WIAG-Pers-CANON-52460-001  022-04302-001
# 10763    62508      WIAG-Pers-CANON-49204-001  037-00828-001
# 10774    39552      WIAG-Pers-CANON-25045-001  072-01315-001
# 10777    62530      WIAG-Pers-CANON-49137-001  022-02525-001
# 10780    53034      WIAG-Pers-CANON-49464-001  074-02238-001
# 10784    29210      WIAG-Pers-CANON-10099-001  032-01416-001
# 10791    36691      WIAG-Pers-CANON-17998-001  054-01124-001
# 10797    53018      WIAG-Pers-CANON-49480-001  712-00430-001
# 10809    62560      WIAG-Pers-CANON-91682-001  086-00792-001
# 10822    33874      WIAG-Pers-CANON-15167-001  014-03860-001
# 10823    37020      WIAG-Pers-CANON-18329-001  054-02830-001
# 10860    62708      WIAG-Pers-CANON-10151-001  029-01073-001
# 10863    37044      WIAG-Pers-CANON-18305-001  014-00397-001
# 10865    29116      WIAG-Pers-CANON-10013-001  014-00398-001
# 10866    62710      WIAG-Pers-CANON-17731-001  032-00254-001
# 10871    60810  WIAG-Pers-EPISCGatz-10668-001  082-00900-001
# 10872    62212      WIAG-Pers-CANON-53449-001  007-00982-001
# 10900    62224      WIAG-Pers-CANON-53455-001  036-02458-001
# 10901    62400      WIAG-Pers-CANON-53518-001  054-01678-001
# 10910    62282      WIAG-Pers-CANON-53482-001  006-00165-001
# 10920    62862      WIAG-Pers-CANON-53540-001  007-01580-001
# 10921    62316      WIAG-Pers-CANON-53494-001  006-00171-001
# 10922    61310      WIAG-Pers-CANON-53083-001  007-01588-001
# 10923    62614      WIAG-Pers-CANON-53580-001  071-00826-001
# 10928    62730      WIAG-Pers-CANON-53624-001  007-03350-001
#
#                       wiag_id_pd   id_pd  gsn_table_id
# 10564  WIAG-Pers-CANON-83871-001  218807        188646
# 10585  WIAG-Pers-CANON-81202-001   75990         63028
# 10631  WIAG-Pers-CANON-81011-001   24005         11132
# 10637  WIAG-Pers-CANON-83974-001  224376        131866
# 10639  WIAG-Pers-CANON-91097-001  331721        383286
# 10652  WIAG-Pers-CANON-84016-001  224792        190951
# 10666  WIAG-Pers-CANON-88020-001  320592        362807
# 10688  WIAG-Pers-CANON-84557-001  274841        205391
# 10698  WIAG-Pers-CANON-85563-001  299073        316032
# 10704  WIAG-Pers-CANON-85631-001  300675        323258
# 10714  WIAG-Pers-CANON-80245-001    8790        206699
# 10718  WIAG-Pers-CANON-88038-001  321547        364875
# 10722  WIAG-Pers-CANON-88973-001  145723        220798
# 10732  WIAG-Pers-CANON-88617-001  325753        374228
# 10735  WIAG-Pers-CANON-88270-001  321734        365236
# 10763  WIAG-Pers-CANON-91315-001  147613        107622
# 10774  WIAG-Pers-CANON-85142-001  291283        297426
# 10777  WIAG-Pers-CANON-81227-001   79309         66333
# 10780  WIAG-Pers-CANON-91316-001  295201        309715
# 10784  WIAG-Pers-CANON-91054-001  339014        402362
# 10791  WIAG-Pers-CANON-83970-001  224334        131824
# 10797  WIAG-Pers-CANON-91322-001  332153        384554
# 10809  WIAG-Pers-CANON-16489-001  338018        396842
# 10822  WIAG-Pers-CANON-90955-001  331169        382568
# 10823  WIAG-Pers-CANON-88172-001  338402        397676
# 10860  WIAG-Pers-CANON-91046-001  338422        397754
# 10863  WIAG-Pers-CANON-81120-001  339020        402374
# 10865  WIAG-Pers-CANON-88221-001  338954        402152
# 10866  WIAG-Pers-CANON-91049-001  126960         99565
# 10871  WIAG-Pers-CANON-88519-001  324963        370898
# 10872  WIAG-Pers-CANON-90775-001  330914        381992
# 10900  WIAG-Pers-CANON-83507-001  143632        168664
# 10901  WIAG-Pers-CANON-84026-001  224888        191047
# 10910  WIAG-Pers-CANON-84886-001  285231        293753
# 10920  WIAG-Pers-CANON-80976-001   23402         10531
# 10921  WIAG-Pers-CANON-84890-001  285237        293759
# 10922  WIAG-Pers-CANON-80978-001   23410         10539
# 10923  WIAG-Pers-CANON-89887-001  330662        381389
# 10928  WIAG-Pers-CANON-81040-001   25172         12297

# %% [markdown]
# ## Generate sql file to run on Personenregister
#
# After generating the file, please open the PR database on phpmyAdmin and run the sql generated there. You can do this by copying the text in the file and pasting it as sql in the interface.
#
# Note: Please do a quick check to see if there are a reasonable number of lines in the sql file (for eg: 20-200). If there are thousands of lines, this might indicate that something has gone wrong.
#
# Another way to check if the generated SQL file is correct is by checking the PR ids. In the SQL file you will find lines with `-- id: <pr_id>`. Please copy the id at the end of the following url: `https://personendatenbank.germania-sacra.de/index/gsn/<pr_id>` and check if the wiag id noted there is missing or is incorrect by clicking on the link.

# %%
query = "LOCK TABLES persons WRITE;\n"
for _, row in unequal_df.iterrows():
    query += f"""
    UPDATE persons
    SET wiag = '{row['wiag_id_wiag']}'
    WHERE id = {row['id_pd']}; -- id: {row['pd_id']}
"""
query += "\nUNLOCK TABLES;"
with open(os.path.join(output_path, f'update_personen_register_{today_string}.sql'), 'w') as file:
    file.write(query)

# %% [markdown]
# # Identical records in wiag
#
# Output is the gsn id of such records. Such entries are displayed with more detailed and should be fixed manually. The end of this notebook deals with such cases.
#
# (The code below works on people with more than one entry in wiag with the same gsn id.)
#
# Note: 046-02872-001 is expected to be present. (You can look at it on [wiag here](https://wiag-vocab.adw-goe.de/id/WIAG-Pers-EPISCGatz-03210-001)).

# %%
gp_df = ic_df.groupby('pd_id').count()
duplicate_wiag_gsns = gp_df[gp_df['id'] > 1].index.to_list()
duplicate_wiag_gsns
# Out:
# []

# %%
ic_df = ic_df[~ic_df['pd_id'].isin(duplicate_wiag_gsns)]

# %%
dupl_ppl = orig_ic_df[orig_ic_df['pd_id'].isin(duplicate_wiag_gsns)]
dupl_ppl
# Out:
#          id                        wiag_id          pd_id
# 1319  17819  WIAG-Pers-EPISCGatz-21305-001  046-02872-001
# 9645  14702  WIAG-Pers-EPISCGatz-03210-001  046-02872-001

# %%
dupl_join_df = dupl_ppl.merge(pr_df, on='pd_id', suffixes=('_wiag', '_pd'))
dupl_join_df
# Out:
#    id_wiag                   wiag_id_wiag          pd_id  \
# 0    17819  WIAG-Pers-EPISCGatz-21305-001  046-02872-001
# 1    14702  WIAG-Pers-EPISCGatz-03210-001  046-02872-001
# 2    59583      WIAG-Pers-CANON-25464-001  082-00384-001
# 3    60772      WIAG-Pers-CANON-25465-001  082-00384-001
#
#                       wiag_id_pd   id_pd  gsn_table_id
# 0  WIAG-Pers-EPISCGatz-03210-001  334165        390910
# 1  WIAG-Pers-EPISCGatz-03210-001  334165        390910
# 2      WIAG-Pers-CANON-25464-001  324601        370382
# 3      WIAG-Pers-CANON-25464-001  324601        370382

# %% [markdown]
# ## Manually fix the following entries on personendatenbank if the code below produces any output

# %%
for gsn in duplicate_wiag_gsns:
    pd_wiag_id = pr_df[pr_df['pd_id'] == gsn]['wiag_id'].values[0]
    
    if len(dupl_ppl[dupl_ppl['wiag_id'] == pd_wiag_id]) == 0:
        # latest wiag id absent in pr
        print(dupl_ppl[dupl_ppl['pd_id'] == gsn])
